# %% [markdown]
# # Traning for SY 1.9 & 2.0

# %%
import torch
from torch import nn, optim
import torch.nn.functional as F
import time
import os
import datetime
import glob
import csv

import torchvision
from torch.utils.data import DataLoader, TensorDataset, ConcatDataset, random_split
from torchvision import transforms

import pandas as pd
import seaborn as sns

from numpy import genfromtxt

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## define functions

# %%
def plotSpec(seyfert,n):
    if seyfert == 1.9:
        plt.plot(np.linspace(3800,7500,7500-3800+1), sy19_feature[n].tolist())
    if seyfert == 2:
        plt.plot(np.linspace(3800,7500,7500-3800+1), sy2_feature[n].tolist())
        
def plotData(data):
        plt.plot(np.linspace(3800,len(data)-1+3800,len(data)), data.tolist(),linewidth=1)
        
def plotFilters(filters):
    filters = filters.flatten()[1:-1].reshape(-1,2)
    for x in filters:
        plt.axvspan(x[0]+3800, x[1]+3800, alpha=0.5, facecolor='grey')
        
def sizeMap(inputSize):
    IN = inputSize
    C1 = (inputSize-50)+1
    S2 = int(C1/2)
    C3 = (S2-50)+1
    S4 = int(C3/2)
    return IN, C1, S2, C3, S4


def read_data(filename, delimiter=','):
    with open(filename, 'r') as my_file:
        reader = csv.reader(my_file, delimiter=delimiter)
        my_list = list(reader)[0]
        my_list= [float(i) for i in my_list]
        return my_list

# %% [markdown]
# ## AGN Emission Lines (3000 - 8000 A)
# https://ned.ipac.caltech.edu/level5/Netzer/Netzer2_1.html
#
# ```
# CIII λ977
# OVI λ1035
# Lα
# NV λ1240
# OI λ1304
# CII λ1336
# SiIV,OIV] λ1400
# NIV] λ1486
# CIV λ1549
# HeII λ1640
# OIII] λ1663
# NIII] λ1750
# CIII] λ1909
# FeII λ(2200-2800)
# MgII λ2798
# [NeV] λ3426
# [OII] λ3727
# [NeIII] λ3869
# HeII λ4686
# Hβ λ4861
# [OIII] λ4959,5007
# FeII λ(4500-5400)
# HeI λ5876
# [FeVII] λ6087
# [OI] λ6300
# [FeX] λ6374
# Hα λ6563
# [NII] λ6583
# [SII] λ6716,6731
# CaII λ8498-8662
# [SIII] λ9069,9532
# ```
#
# The emission line spectrum of active galactic nuclei and the unifying scheme
# https://link.springer.com/article/10.1007%2Fs001590000006
#
# ```
# (Broad permmited lines)
# HI, HeI λλ5876,6678,7065
# He II λ4686
# Fe II visible domain
#
# (narrow line)
# [Fe VII] λ6087
# [Fe X] λ6375
# [Fe XI] λ7892
# ```
#
# add more balmer lines
# ```
# Hγ λ4340
# H-δ λ4102
# ```
#
#
# FeII Lines, Table I in
# https://arxiv.org/pdf/1004.2212.pdf
#
#
# without FeII:
#
# lines = [3869,4102,4340,4686,4861,4959,5007,5876,6087,6300,6374,6563,6583,6678,6716,6731,7065]
#
#
# with Fe II:
#
# lines = [3869,4102,4340,4473,4489,4491,4508,4515,4520,4523,4534,4542,4549,4556,4576,4583,4621,4629,4667,4686,4731,4861,4924,4959,4993,5007,5018,5146,5169,5198,5235,5265,5276,5284,5317,5326,5338,5363,5414,5425,5876,6087,6300,6374,6563,6583,6678,6716,6731,7065]

# %%
def _filters(lines, width, Ha_width=280, Hb_width=120, Hg_width=60):
    boundery_00 = np.array([3800,4500])
    boundery_0 = np.array([[line-width/2,line+width/2] for line in lines if line<4338]).flatten()
    boundery_Hg = np.array([4340-Hg_width/2,4340+Hg_width/2]).flatten()
    boundery_1 = np.array([[line-width/2,line+width/2] for line in lines if (line>4342 and line<4860)]).flatten()
    boundery_Hb = np.array([4861-Hb_width/2,4861+Hb_width/2]).flatten()
    boundery_2 = np.array([[line-width/2,line+width/2] for line in lines if (line>4862 and line<6560)]).flatten()
    boundery_Ha = np.array([6563-Ha_width/2,6563+Ha_width/2]).flatten()
    boundery_3 = np.array([[line-width/2,line+width/2] for line in lines if line>6566]).flatten()
    boundery = np.concatenate((boundery_00,boundery_0, boundery_Hg, boundery_1,boundery_Hb,boundery_2,boundery_Ha,boundery_3),axis=0).reshape(-1,2)
    # 1st filter, filter the right boundery, ignore those right right bouderies smaller than the previous one
    index = [1]
    while len(index):
        signs = np.sign(boundery[1:]-boundery[:-1])
        index = np.argwhere(signs==-1)[:,0]+1
        if len(index)>0:
            boundery = np.delete(boundery,index,0)
    #print(boundery)
    # 2nd filter, compare right boundery and next left boundery, if smaller, merge two intervals.
    boundery = boundery.flatten()
    filters = []
    filters.append(boundery[0]) 
    i = 1
    while i< (len(boundery)-1):
        if boundery[i]<boundery[i+1]:
            filters.append(boundery[i])
            i=i+1
        else: 
            i=i+2
    filters.append(boundery[-1])
    return np.array(filters).reshape(-1,2)

def _filterTensor(tensor, lines, width, begin=3800, end=7500):
    filters = _filters(lines, width).flatten()
    filters = np.insert(filters,0,begin)
    filters = np.append(filters,end)
    filters = filters.reshape(-1,2)
    filters = (filters-3800).astype(int)
    if len(tensor.size()) == 1:
        return torch.cat([tensor[f[0]:f[1]] for f in filters],dim=1), filters
    else:
        return torch.cat([tensor[:,f[0]:f[1]] for f in filters],dim=1), filters

# %% [markdown]
# ## read  data

# %%
# The feature size is 1x(7500-3800+1), a pixel to one wavelenght
# merge data in previouly defined in different files
sy19_feature_train = read_data('type1-pixels-3800-7500-redshifted-normalized-train.csv', delimiter=',')
sy19_feature_test = read_data('type1-pixels-3800-7500-redshifted-normalized-test.csv', delimiter=',')
sy20_feature_1 = read_data('sy20-pixels-3800-7500-redshifted-normalized.csv', delimiter=',')
sy20_feature_2 = read_data('sy20-test-pixels-3800-7500-redshifted-normalized.0.csv', delimiter=',')
sy20_feature_3 = read_data('sy20-test-pixels-3800-7500-redshifted-normalized.1.csv', delimiter=',')
sy20_feature_4 = read_data('sy20-test-pixels-3800-7500-redshifted-normalized.2.csv', delimiter=',')
sy20_feature_5 = read_data('sy20-test-pixels-3800-7500-redshifted-normalized.3.csv', delimiter=',')
sy20_feature_6 = read_data('sy20-test-pixels-3800-7500-redshifted-normalized.4.csv', delimiter=',')
sy20_feature_7 = read_data('sy20-test-pixels-3800-7500-redshifted-normalized.5.csv', delimiter=',')
sy20_feature_8 = read_data('sy20-test-pixels-3800-7500-redshifted-normalized.6.csv', delimiter=',')

# %%
## read sy19 with noise   
#sy19_noise_feature_train = []
#for file in glob.glob('sy19-pixels*noise*'):
#    print('reading:', file)
#    file_feature = read_data(file, delimiter=',')
#    sy19_noise_feature_train = np.concatenate((sy19_noise_feature_train, file_feature), axis=0)
#
#sy19_noise_feature_test = []
#for file in glob.glob('sy19-test*noise*'):
#    print('reading:', file)
#    file_feature = read_data(file, delimiter=',')
#    sy19_noise_feature_test = np.concatenate((sy19_noise_feature_test, file_feature), axis=0)

# %%
##  Small sample pre-traning
#sy19_feature = sy19_feature_1
#sy20_feature = sy20_feature_1

## Full sample
#sy19_feature_train = np.concatenate((sy19_feature_train,  sy19_noise_feature_train), axis=0)
sy20_feature = np.concatenate((sy20_feature_1, sy20_feature_2,sy20_feature_3,sy20_feature_4,\
                               sy20_feature_5,sy20_feature_6,sy20_feature_7,sy20_feature_8), axis=0)

sy19_feature_train = torch.Tensor(sy19_feature_train).view(-1,7500-3800+1)
sy19_feature_test = torch.Tensor(sy19_feature_test).view(-1,7500-3800+1)
sy20_feature = torch.Tensor(sy20_feature).view(-1,7500-3800+1)

# %%
# filter wavelength
lines = [3869,4102,4340,4473,4489,4491,4508,4515,4520,4523,4534,4542,4549,4556,4576,4583,4621,4629,4667,4686,4731,4861,4924,4959,4993,5007,5018,5146,5169,5198,5235,5265,5276,5284,5317,5326,5338,5363,5414,5425,5876,6087,6300,6374,6563,6583,6678,6716,6731,7065]
width = 50

sy19_feature_train_filtered, filters = _filterTensor(sy19_feature_train, lines, width, begin=3800, end=7500)
sy19_feature_test_filtered, filters = _filterTensor(sy19_feature_test, lines, width, begin=3800, end=7500)
sy20_feature_filtered, filters = _filterTensor(sy20_feature, lines, width, begin=3800, end=7500)

# %%
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(12,6), sharex=True, sharey=True)
plt.subplots_adjust(wspace = 0.05)
for i in range(20):
    plt.sca(axs[0])
    axs[0].set_yticklabels([])
    plotData(sy19_feature_test[i]+i/5)
plotFilters(filters)
plt.legend(title='Seyfert 1s',loc=2)
for i in range(20):
    plt.sca(axs[1])
    axs[1].set_yticklabels([])
    plotData(sy20_feature[i]+i/5)
plotFilters(filters)
plt.legend(title='Seyfert 2',loc=2)


plt.xlim(3800,7500)

plt.ylabel('Density')
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# Text(0, 0.5, 'Density')

# %%
# classify 1.9 as 1, and 2 as 0. 
sy19_label_train = torch.ones(sy19_feature_train.size(0),dtype=torch.long)
sy19_label_test = torch.ones(sy19_feature_test.size(0),dtype=torch.long)
sy20_label = torch.zeros(sy20_feature.size(0),dtype=torch.long)

# create indices
sy19_indice_train = torch.linspace(0,len(sy19_feature_train)-1,len(sy19_feature_train)).int()
sy19_indice_test = torch.linspace(0,len(sy19_feature_test)-1,len(sy19_feature_test)).int()
sy20_indice = torch.linspace(0,len(sy20_feature)-1,len(sy20_feature)).int()

# taking same number of 1.9 and 2.0 seyfert galaxies
sy19_dataset_train = TensorDataset(sy19_indice_train,sy19_feature_train_filtered,sy19_label_train)
sy19_dataset_test = TensorDataset(sy19_indice_test,sy19_feature_test_filtered,sy19_label_test)

sy20_dataset_train = TensorDataset(sy20_indice[:len(sy19_dataset_train)],sy20_feature_filtered[:len(sy19_dataset_train)],sy20_label[:len(sy19_dataset_train)])
sy20_dataset_test = TensorDataset(sy20_indice[len(sy19_dataset_train):],sy20_feature_filtered[len(sy19_dataset_train):],sy20_label[len(sy19_dataset_train):])

# merge the test dataset
dataset = ConcatDataset((sy19_dataset_train,sy20_dataset_train))

# %% [markdown]
# ## CNN Network - One layer of Full CNN

# %% [markdown]
# ### computing output size of image
#
#
# - i = input
# - o = output
# - p = padding
# - k = kernel_size
# - s = stride
# - d = dilation
#
# o = [i + 2*p - k - (k-1)*(d-1)]/s + 1
#
# In your case this gives o = [32 + 2 - 3 - 2*1]/1 +1 = [29] + 1 = 30.
# Now, you could set all your parameters and “solve” the equation for p.
# You will see, that p=2 will give you an output size of 32.
#
# You could  with some tools like ezyang’s convolution visualizer 308 or calculate it with this formula:
# https://ezyang.github.io/convolution-visualizer/index.html

# %% [markdown]
# ###  Network Map
#
# | Layer | Type | Maps | Kernel_size | Padding | Stride | Image_size | Activation | Comment |
# | --- | --- | --- | --- | --- | --- | --- | --- | --- |
# |  Out | Linear | - | - | - | - | 2 | - |  |
# |  F7 | Linear | - | - | - | - | 100 | ReLU | 1000 -> 100  |
# |  D6 | Dropout (0.5) | - | - | - | - | - | - | - |
# |  C5 | Convolution | 1000 | 888 | 0 | 1 | 1 | ReLU |  |
# |  S4 | Avg Pooling | 128 | 2 | 0 | 2 | 888 | - |  |
# |  C3 | Convolution | 128 | 50 | 0 | 1 | 1777 | ReLU |  |
# |  S2 | Avg Pooling | 64 | 2 | 0 | 2 | 1826 | - |  |
# |  C1 | Convolution | 64 | 50 | 0 | 1 | 3652 | ReLU |  |
# | In | Input | 1 | - | - |- | 3701 |- | |

# %%
sizes = sizeMap(sy19_feature_test_filtered[1].size(0))

# %%
sizes
# Out:
# (1591, 1542, 771, 722, 361)

# %%
class simpleCNN(nn.Module):
    
    def __init__(self):
        super(simpleCNN, self).__init__()
        self.C1 = nn.Conv1d(1, 64, 50)
        self.S2 = nn.AvgPool1d(2, stride=2)
        self.C3 = nn.Conv1d(64, 128, 50)
        self.S4 = nn.AvgPool1d(2, stride=2)
        self.C5 = nn.Conv1d(128, 1000, sizes[4])
        self.D6 = nn.Dropout(0.5)
        self.F7 = nn.Linear(1000, 100)
        self.Out= nn.Linear(100, 2)
        
    def forward(self, x):
        x = F.relu(self.C1(x),inplace=True)
        x = self.S2(x)
        x = F.relu(self.C3(x),inplace=True)
        x = self.S4(x)
        x = F.relu(self.C5(x),inplace=True)
        x = self.D6(x)
        x = x.view(x.size(0),-1)
        x = F.relu(self.F7(x),inplace=True)
        x = self.Out(x)
        return x

# %%
net = simpleCNN()
print(net)
# Out:
# simpleCNN(
#   (C1): Conv1d(1, 64, kernel_size=(50,), stride=(1,))
#   (S2): AvgPool1d(kernel_size=(2,), stride=(2,), padding=(0,))
#   (C3): Conv1d(64, 128, kernel_size=(50,), stride=(1,))
#   (S4): AvgPool1d(kernel_size=(2,), stride=(2,), padding=(0,))
#   (C5): Conv1d(128, 1000, kernel_size=(361,), stride=(1,))
#   (D6): Dropout(p=0.5, inplace=False)
#   (F7): Linear(in_features=1000, out_features=100, bias=True)
#   (Out): Linear(in_features=100, out_features=2, bias=True)
# )

# %%
## Test
x = torch.randn(5,1,sizes[0])
net(x)
# Out:
# tensor([[-0.0748,  0.1087],
#         [-0.0488,  0.1051],
#         [-0.0537,  0.1234],
#         [-0.0432,  0.0988],
#         [-0.0431,  0.1170]], grad_fn=<AddmmBackward>)

# %% [markdown]
# ### Check GPU availabel

# %%
use_gpu = torch.cuda.is_available()
if use_gpu:
    net.cuda(3)
    device = torch.device('cuda:3')
    print ('USE GPU')
else:
    device = torch.device('cpu')
    print ('USE CPU')
# Out:
# USE GPU

# %% [markdown]
# ### define  accuracy

# %%
def accuracy(y_hat, y):
#    y_hat = torch.sign(y_hat)
    return (y_hat.argmax(dim=1) == y).float().mean().item()

def evaluate_accuracy(data_iter, net, device):
    acc = torch.tensor([0.0], device=device)
    for (index, img, label) in data_iter:
        img = img.view(-1,1,sizes[0])
        # 如果 device 是 GPU，将数据复制到 GPU 上。
        if use_gpu:
            index, img, label = index.to(device), img.to(device), label.to(device)
        acc += accuracy(net(img), label)
    return acc.item() / len(data_iter)

# %% [markdown]
# ### TRAINING

# %%
learning_rate = 0.01

loss = nn.CrossEntropyLoss() # 包含了softmax 和 cross entropy
optimizer = optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9)
#optimizer = optim.Adam(net.parameters(), lr=learning_rate, betas=(0.9,0.999), eps=1e-8)
#optimizer = optim.SGD(net.parameters(), lr=learning_rate)

# %%
num_epochs = 500

batch_size = 64
train_iter = DataLoader(dataset, batch_size=batch_size, shuffle=True, num_workers=4)

# %%
## laod previous traning results
#
#net.load_state_dict(torch.load('cuda3-GOOD.pt'))
#
#previous = pd.read_csv('./runs/acc-list-cuda3-2019-07-22-15-02-10-826651-GOOD.csv', header=0, comment='#')
#
#loss_list = list(previous['loss'])
#sy19_test_acc_list = list(previous['sy19_test_acc'])
#sy20_test_acc_list = list(previous['sy20_test_acc'])
#train_acc_list = list(previous['train_acc'])

# %%
sy19_test_acc_list = []
sy20_test_acc_list = []
train_acc_list = []
loss_list = []

# %%
for epoch in range(num_epochs):
    net.train() 
    start = time.time()
    train_l_sum = 0.
    train_acc_sum = 0.
    for (index, img, label) in train_iter:
        img = img.view(-1,1,sizes[0])
        if use_gpu:
            index, img, label = index.to(device), img.to(device), label.to(device)
        optimizer.zero_grad()
        predict = net(img)
        l = loss(predict, label.view(-1))
        l.backward()
        optimizer.step()
        train_l_sum += l.data.item()
        train_acc_sum += accuracy(predict, label.view(-1))
        #print(l)
    
    if ((epoch+1)%1 ==0):
        net.eval() 
        sy19_test_iter = DataLoader(sy19_dataset_test, batch_size=batch_size, shuffle=True, num_workers=4)
        sy19_test_acc = evaluate_accuracy(sy19_test_iter, net, device)
        sy20_test_iter = DataLoader(sy20_dataset_test, batch_size=batch_size, shuffle=True, num_workers=4)
        sy20_test_acc = evaluate_accuracy(sy20_test_iter, net, device)
        
        print('epoch %d, loss %.6f, train acc %.6f, sy19 test acc  %.4f, sy20 test acc  %.4f, '
                'time %.1f sec' % (epoch + 1, train_l_sum / len(train_iter),
                                    train_acc_sum / len(train_iter),
                                    sy19_test_acc, sy20_test_acc, time.time() - start))
        sy19_test_acc_list.append(sy19_test_acc)
        sy20_test_acc_list.append(sy20_test_acc)
        loss_list.append(train_l_sum / len(train_iter))
        train_acc_list.append(train_acc_sum / len(train_iter))
        if (train_l_sum / len(train_iter) < 0.5):
            learning_rate = 0.001
            optimizer = optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9)
        if (train_l_sum / len(train_iter) < 0.005):
            learning_rate = 0.0001
            optimizer = optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9)
# Out:
# epoch 1, loss 0.576757, train acc 0.680613, sy19 test acc  0.8199, sy20 test acc  0.5963, time 33.9 sec
# epoch 2, loss 0.564869, train acc 0.695186, sy19 test acc  0.7970, sy20 test acc  0.6526, time 33.3 sec
# epoch 3, loss 0.565012, train acc 0.696127, sy19 test acc  0.8737, sy20 test acc  0.4697, time 34.2 sec
# epoch 4, loss 0.561350, train acc 0.695629, sy19 test acc  0.6129, sy20 test acc  0.7260, time 33.0 sec
# epoch 5, loss 0.565913, train acc 0.687057, sy19 test acc  0.8910, sy20 test acc  0.4363, time 33.9 sec
# epoch 6, loss 0.555636, train acc 0.702350, sy19 test acc  0.8468, sy20 test acc  0.6102, time 32.9 sec
# epoch 7, loss 0.556895, train acc 0.706043, sy19 test acc  0.8678, sy20 test acc  0.5109, time 33.8 sec
# epoch 8, loss 0.555618, train acc 0.704556, sy19 test acc  0.5794, sy20 test acc  0.8078, time 33.1 sec
# epoch 9, loss 0.547329, train acc 0.713057, sy19 test acc  0.6820, sy20 test acc  0.7630, time 33.4 sec
# epoch 10, loss 0.536144, train acc 0.721628, sy19 test acc  0.8763, sy20 test acc  0.5713, time 33.2 sec
# epoch 11, loss 0.546932, train acc 0.704390, sy19 test acc  0.7161, sy20 test acc  0.7024, time 34.3 sec
# epoch 12, loss 0.541173, train acc 0.717809, sy19 test acc  0.7356, sy20 test acc  0.7559, time 33.4 sec
# epoch 13, loss 0.540452, train acc 0.714867, sy19 test acc  0.6386, sy20 test acc  0.7854, time 33.7 sec
# epoch 14, loss 0.539460, train acc 0.717414, sy19 test acc  0.7506, sy20 test acc  0.7166, time 33.7 sec
# epoch 15, loss 0.526566, train acc 0.723281, sy19 test acc  0.7938, sy20 test acc  0.6624, time 33.5 sec
# epoch 16, loss 0.521865, train acc 0.726634, sy19 test acc  0.7495, sy20 test acc  0.7146, time 33.3 sec
# epoch 17, loss 0.532824, train acc 0.724024, sy19 test acc  0.7990, sy20 test acc  0.6482, time 33.4 sec
# epoch 18, loss 0.519188, train acc 0.727187, sy19 test acc  0.5980, sy20 test acc  0.8273, time 33.8 sec
# epoch 19, loss 0.517700, train acc 0.734691, sy19 test acc  0.8105, sy20 test acc  0.6368, time 34.0 sec
# epoch 20, loss 0.523735, train acc 0.730129, sy19 test acc  0.6492, sy20 test acc  0.8058, time 33.9 sec
# epoch 21, loss 0.514875, train acc 0.735300, sy19 test acc  0.7996, sy20 test acc  0.6716, time 34.0 sec
# epoch 22, loss 0.523105, train acc 0.723186, sy19 test acc  0.8249, sy20 test acc  0.6294, time 33.8 sec
# epoch 23, loss 0.508276, train acc 0.739309, sy19 test acc  0.8259, sy20 test acc  0.6508, time 34.5 sec
# epoch 24, loss 0.516877, train acc 0.731441, sy19 test acc  0.5652, sy20 test acc  0.8494, time 33.4 sec
# epoch 25, loss 0.509612, train acc 0.729393, sy19 test acc  0.7046, sy20 test acc  0.7511, time 34.4 sec
# epoch 26, loss 0.503995, train acc 0.741800, sy19 test acc  0.6583, sy20 test acc  0.7748, time 34.4 sec
# epoch 27, loss 0.513740, train acc 0.731244, sy19 test acc  0.7451, sy20 test acc  0.7136, time 33.6 sec
# epoch 28, loss 0.506695, train acc 0.741167, sy19 test acc  0.8057, sy20 test acc  0.6231, time 34.4 sec
# epoch 29, loss 0.495566, train acc 0.749130, sy19 test acc  0.8029, sy20 test acc  0.6792, time 33.4 sec
# epoch 30, loss 0.469791, train acc 0.765546, sy19 test acc  0.7860, sy20 test acc  0.7023, time 34.4 sec
# epoch 31, loss 0.459862, train acc 0.774924, sy19 test acc  0.7910, sy20 test acc  0.7043, time 34.1 sec
# epoch 32, loss 0.461700, train acc 0.774276, sy19 test acc  0.7634, sy20 test acc  0.7250, time 33.9 sec
# epoch 33, loss 0.460485, train acc 0.775019, sy19 test acc  0.7886, sy20 test acc  0.7037, time 34.2 sec
# epoch 34, loss 0.455837, train acc 0.777866, sy19 test acc  0.7779, sy20 test acc  0.7055, time 33.7 sec
# epoch 35, loss 0.452503, train acc 0.780222, sy19 test acc  0.8079, sy20 test acc  0.6879, time 34.0 sec
# epoch 36, loss 0.453783, train acc 0.776316, sy19 test acc  0.8175, sy20 test acc  0.6697, time 33.7 sec
# epoch 37, loss 0.450927, train acc 0.783939, sy19 test acc  0.8299, sy20 test acc  0.6635, time 33.8 sec
# epoch 38, loss 0.453820, train acc 0.778269, sy19 test acc  0.8290, sy20 test acc  0.6710, time 33.9 sec
# epoch 39, loss 0.449282, train acc 0.779787, sy19 test acc  0.7819, sy20 test acc  0.7115, time 33.9 sec
# epoch 40, loss 0.450263, train acc 0.784476, sy19 test acc  0.7838, sy20 test acc  0.7144, time 34.2 sec
# epoch 41, loss 0.448496, train acc 0.780625, sy19 test acc  0.8040, sy20 test acc  0.6912, time 33.7 sec
# epoch 42, loss 0.448434, train acc 0.783678, sy19 test acc  0.8059, sy20 test acc  0.6779, time 33.7 sec
# epoch 43, loss 0.446835, train acc 0.784041, sy19 test acc  0.8381, sy20 test acc  0.6446, time 33.8 sec
# epoch 44, loss 0.443801, train acc 0.782325, sy19 test acc  0.7825, sy20 test acc  0.7089, time 34.2 sec
# epoch 45, loss 0.442431, train acc 0.785093, sy19 test acc  0.7879, sy20 test acc  0.7185, time 33.6 sec
# epoch 46, loss 0.442382, train acc 0.785781, sy19 test acc  0.7936, sy20 test acc  0.6986, time 33.8 sec
# epoch 47, loss 0.443655, train acc 0.786643, sy19 test acc  0.8242, sy20 test acc  0.6703, time 34.0 sec
# epoch 48, loss 0.440298, train acc 0.788841, sy19 test acc  0.8231, sy20 test acc  0.6792, time 34.4 sec
# epoch 49, loss 0.441153, train acc 0.786184, sy19 test acc  0.7988, sy20 test acc  0.7048, time 34.0 sec
# epoch 50, loss 0.437681, train acc 0.791648, sy19 test acc  0.7964, sy20 test acc  0.7021, time 34.3 sec
# epoch 51, loss 0.441045, train acc 0.788730, sy19 test acc  0.7990, sy20 test acc  0.7003, time 33.9 sec
# epoch 52, loss 0.438840, train acc 0.791949, sy19 test acc  0.8092, sy20 test acc  0.6792, time 34.3 sec
# epoch 53, loss 0.436547, train acc 0.793601, sy19 test acc  0.7931, sy20 test acc  0.7063, time 33.7 sec
# epoch 54, loss 0.435708, train acc 0.793499, sy19 test acc  0.7836, sy20 test acc  0.7048, time 34.0 sec
# epoch 55, loss 0.434319, train acc 0.792439, sy19 test acc  0.7747, sy20 test acc  0.7275, time 33.9 sec
# epoch 56, loss 0.432156, train acc 0.796448, sy19 test acc  0.7931, sy20 test acc  0.7053, time 33.9 sec
# epoch 57, loss 0.435067, train acc 0.792289, sy19 test acc  0.8138, sy20 test acc  0.6884, time 33.5 sec
# epoch 58, loss 0.433761, train acc 0.792558, sy19 test acc  0.8109, sy20 test acc  0.6863, time 33.5 sec
# epoch 59, loss 0.430940, train acc 0.794954, sy19 test acc  0.8079, sy20 test acc  0.6936, time 33.8 sec
# epoch 60, loss 0.431517, train acc 0.791846, sy19 test acc  0.8105, sy20 test acc  0.6907, time 34.1 sec
# epoch 61, loss 0.428277, train acc 0.798599, sy19 test acc  0.7945, sy20 test acc  0.7131, time 34.3 sec
# epoch 62, loss 0.426723, train acc 0.796907, sy19 test acc  0.8131, sy20 test acc  0.6884, time 34.6 sec
# epoch 63, loss 0.426570, train acc 0.797294, sy19 test acc  0.8103, sy20 test acc  0.6841, time 33.8 sec
# epoch 64, loss 0.426949, train acc 0.797998, sy19 test acc  0.8214, sy20 test acc  0.6828, time 35.3 sec
# epoch 65, loss 0.426966, train acc 0.796907, sy19 test acc  0.8251, sy20 test acc  0.6716, time 34.2 sec
# epoch 66, loss 0.422808, train acc 0.799121, sy19 test acc  0.7857, sy20 test acc  0.7159, time 34.6 sec
# epoch 67, loss 0.425888, train acc 0.798567, sy19 test acc  0.7721, sy20 test acc  0.7230, time 33.8 sec
# epoch 68, loss 0.422289, train acc 0.797658, sy19 test acc  0.7684, sy20 test acc  0.7382, time 34.4 sec
# epoch 69, loss 0.423432, train acc 0.802110, sy19 test acc  0.7811, sy20 test acc  0.7123, time 34.0 sec
# epoch 70, loss 0.424237, train acc 0.798646, sy19 test acc  0.7751, sy20 test acc  0.7232, time 34.2 sec
# epoch 71, loss 0.421968, train acc 0.799801, sy19 test acc  0.7649, sy20 test acc  0.7295, time 33.9 sec
# epoch 72, loss 0.419745, train acc 0.800062, sy19 test acc  0.7994, sy20 test acc  0.6942, time 34.4 sec
# epoch 73, loss 0.418429, train acc 0.805170, sy19 test acc  0.8051, sy20 test acc  0.6983, time 34.1 sec
# epoch 74, loss 0.415515, train acc 0.803059, sy19 test acc  0.8001, sy20 test acc  0.6978, time 34.5 sec
# epoch 75, loss 0.418646, train acc 0.805565, sy19 test acc  0.8036, sy20 test acc  0.6951, time 33.6 sec
# epoch 76, loss 0.417170, train acc 0.802260, sy19 test acc  0.7712, sy20 test acc  0.7197, time 34.3 sec
# epoch 77, loss 0.413183, train acc 0.809021, sy19 test acc  0.7999, sy20 test acc  0.7052, time 33.9 sec
# epoch 78, loss 0.415523, train acc 0.801952, sy19 test acc  0.7905, sy20 test acc  0.7098, time 34.2 sec
# epoch 79, loss 0.409594, train acc 0.808127, sy19 test acc  0.8192, sy20 test acc  0.6753, time 33.7 sec
# epoch 80, loss 0.411603, train acc 0.808222, sy19 test acc  0.8094, sy20 test acc  0.6928, time 34.7 sec
# epoch 81, loss 0.410922, train acc 0.812832, sy19 test acc  0.7970, sy20 test acc  0.6964, time 33.7 sec
# epoch 82, loss 0.408285, train acc 0.812429, sy19 test acc  0.8179, sy20 test acc  0.6707, time 34.2 sec
# epoch 83, loss 0.407411, train acc 0.810136, sy19 test acc  0.7883, sy20 test acc  0.6998, time 34.1 sec
# epoch 84, loss 0.408175, train acc 0.814240, sy19 test acc  0.8183, sy20 test acc  0.6783, time 34.1 sec
# epoch 85, loss 0.409746, train acc 0.804363, sy19 test acc  0.7604, sy20 test acc  0.7373, time 33.9 sec
# epoch 86, loss 0.402791, train acc 0.811235, sy19 test acc  0.7979, sy20 test acc  0.6988, time 34.3 sec
# epoch 87, loss 0.406152, train acc 0.816533, sy19 test acc  0.7866, sy20 test acc  0.7074, time 33.9 sec
# epoch 88, loss 0.398827, train acc 0.814137, sy19 test acc  0.8114, sy20 test acc  0.6843, time 34.3 sec
# epoch 89, loss 0.401728, train acc 0.814888, sy19 test acc  0.8155, sy20 test acc  0.6843, time 34.1 sec
# epoch 90, loss 0.399838, train acc 0.813338, sy19 test acc  0.7962, sy20 test acc  0.7113, time 34.7 sec
# epoch 91, loss 0.401027, train acc 0.816636, sy19 test acc  0.8211, sy20 test acc  0.6794, time 33.9 sec
# epoch 92, loss 0.397135, train acc 0.819087, sy19 test acc  0.8275, sy20 test acc  0.6721, time 35.1 sec
# epoch 93, loss 0.397508, train acc 0.818486, sy19 test acc  0.7747, sy20 test acc  0.7282, time 33.5 sec
# epoch 94, loss 0.395437, train acc 0.814967, sy19 test acc  0.7636, sy20 test acc  0.7310, time 34.2 sec
# epoch 95, loss 0.393476, train acc 0.816050, sy19 test acc  0.8038, sy20 test acc  0.6859, time 34.0 sec
# epoch 96, loss 0.393186, train acc 0.821293, sy19 test acc  0.8005, sy20 test acc  0.6872, time 34.5 sec
# epoch 97, loss 0.393337, train acc 0.821032, sy19 test acc  0.7996, sy20 test acc  0.6950, time 33.8 sec
# epoch 98, loss 0.391403, train acc 0.821949, sy19 test acc  0.8528, sy20 test acc  0.6348, time 34.3 sec
# epoch 99, loss 0.390645, train acc 0.817830, sy19 test acc  0.8240, sy20 test acc  0.6737, time 33.7 sec
# epoch 100, loss 0.387507, train acc 0.823056, sy19 test acc  0.7632, sy20 test acc  0.7293, time 32.4 sec
# epoch 101, loss 0.388699, train acc 0.821000, sy19 test acc  0.8264, sy20 test acc  0.6776, time 32.0 sec
# epoch 102, loss 0.384042, train acc 0.823610, sy19 test acc  0.8175, sy20 test acc  0.6814, time 32.1 sec
# epoch 103, loss 0.383127, train acc 0.825950, sy19 test acc  0.7825, sy20 test acc  0.7053, time 32.0 sec
# epoch 104, loss 0.379962, train acc 0.823452, sy19 test acc  0.7873, sy20 test acc  0.7034, time 32.0 sec
# epoch 105, loss 0.382622, train acc 0.825753, sy19 test acc  0.8111, sy20 test acc  0.6746, time 32.0 sec
# epoch 106, loss 0.379379, train acc 0.826757, sy19 test acc  0.7944, sy20 test acc  0.6858, time 32.0 sec
# epoch 107, loss 0.379584, train acc 0.826852, sy19 test acc  0.7738, sy20 test acc  0.7205, time 32.0 sec
# epoch 108, loss 0.377378, train acc 0.830655, sy19 test acc  0.8225, sy20 test acc  0.6657, time 32.0 sec
# epoch 109, loss 0.374594, train acc 0.828512, sy19 test acc  0.8411, sy20 test acc  0.6551, time 32.1 sec
# epoch 110, loss 0.372098, train acc 0.832118, sy19 test acc  0.8398, sy20 test acc  0.6592, time 32.0 sec
# epoch 111, loss 0.370315, train acc 0.832355, sy19 test acc  0.7994, sy20 test acc  0.6942, time 32.0 sec
# epoch 112, loss 0.366146, train acc 0.837606, sy19 test acc  0.7968, sy20 test acc  0.6905, time 32.0 sec
# epoch 113, loss 0.369361, train acc 0.834277, sy19 test acc  0.7858, sy20 test acc  0.7022, time 32.0 sec
# epoch 114, loss 0.369913, train acc 0.833162, sy19 test acc  0.8329, sy20 test acc  0.6688, time 32.0 sec
# epoch 115, loss 0.370146, train acc 0.834119, sy19 test acc  0.8048, sy20 test acc  0.6741, time 32.0 sec
# epoch 116, loss 0.365122, train acc 0.836372, sy19 test acc  0.7767, sy20 test acc  0.7066, time 32.0 sec
# epoch 117, loss 0.360603, train acc 0.836871, sy19 test acc  0.8058, sy20 test acc  0.6855, time 32.0 sec
# epoch 118, loss 0.361310, train acc 0.837772, sy19 test acc  0.7784, sy20 test acc  0.6996, time 32.1 sec
# epoch 119, loss 0.359312, train acc 0.842738, sy19 test acc  0.8485, sy20 test acc  0.6430, time 32.0 sec
# epoch 120, loss 0.358901, train acc 0.838112, sy19 test acc  0.8205, sy20 test acc  0.6765, time 32.0 sec
# epoch 121, loss 0.355291, train acc 0.839077, sy19 test acc  0.7714, sy20 test acc  0.7078, time 32.0 sec
# epoch 122, loss 0.355702, train acc 0.842129, sy19 test acc  0.7990, sy20 test acc  0.6921, time 32.0 sec
# epoch 123, loss 0.354647, train acc 0.841228, sy19 test acc  0.8492, sy20 test acc  0.6473, time 32.0 sec
# epoch 124, loss 0.353260, train acc 0.841734, sy19 test acc  0.8155, sy20 test acc  0.6725, time 32.0 sec
# epoch 125, loss 0.352955, train acc 0.839678, sy19 test acc  0.7741, sy20 test acc  0.7096, time 32.0 sec
# epoch 126, loss 0.347447, train acc 0.843837, sy19 test acc  0.8092, sy20 test acc  0.6676, time 32.0 sec
# epoch 127, loss 0.344870, train acc 0.845482, sy19 test acc  0.7855, sy20 test acc  0.6980, time 32.1 sec
# epoch 128, loss 0.343790, train acc 0.847941, sy19 test acc  0.8285, sy20 test acc  0.6568, time 32.0 sec
# epoch 129, loss 0.344055, train acc 0.845237, sy19 test acc  0.7793, sy20 test acc  0.7052, time 32.0 sec
# epoch 130, loss 0.346127, train acc 0.840721, sy19 test acc  0.8088, sy20 test acc  0.6718, time 32.0 sec
# epoch 131, loss 0.341227, train acc 0.848447, sy19 test acc  0.7968, sy20 test acc  0.6748, time 32.0 sec
# epoch 132, loss 0.340980, train acc 0.848139, sy19 test acc  0.7996, sy20 test acc  0.6724, time 32.0 sec
# epoch 133, loss 0.340486, train acc 0.848645, sy19 test acc  0.8040, sy20 test acc  0.6813, time 32.0 sec
# epoch 134, loss 0.334612, train acc 0.848392, sy19 test acc  0.8242, sy20 test acc  0.6612, time 32.1 sec
# epoch 135, loss 0.331077, train acc 0.851847, sy19 test acc  0.8513, sy20 test acc  0.6225, time 32.0 sec
# epoch 136, loss 0.336932, train acc 0.849641, sy19 test acc  0.8060, sy20 test acc  0.6742, time 32.0 sec
# epoch 137, loss 0.330325, train acc 0.851056, sy19 test acc  0.8222, sy20 test acc  0.6485, time 32.0 sec
# epoch 138, loss 0.328992, train acc 0.855508, sy19 test acc  0.7712, sy20 test acc  0.7035, time 32.0 sec
# epoch 139, loss 0.330791, train acc 0.850629, sy19 test acc  0.7815, sy20 test acc  0.6964, time 32.0 sec
# epoch 140, loss 0.321793, train acc 0.859517, sy19 test acc  0.8185, sy20 test acc  0.6519, time 32.1 sec
# epoch 141, loss 0.323619, train acc 0.859565, sy19 test acc  0.8066, sy20 test acc  0.6789, time 32.0 sec
# epoch 142, loss 0.319290, train acc 0.861557, sy19 test acc  0.8066, sy20 test acc  0.6714, time 32.0 sec
# epoch 143, loss 0.317504, train acc 0.864863, sy19 test acc  0.7893, sy20 test acc  0.6872, time 32.0 sec
# epoch 144, loss 0.315299, train acc 0.859865, sy19 test acc  0.7621, sy20 test acc  0.7178, time 32.0 sec
# epoch 145, loss 0.316512, train acc 0.860869, sy19 test acc  0.7893, sy20 test acc  0.6924, time 32.0 sec
# epoch 146, loss 0.312124, train acc 0.859913, sy19 test acc  0.7562, sy20 test acc  0.7148, time 32.0 sec
# epoch 147, loss 0.313121, train acc 0.859715, sy19 test acc  0.8048, sy20 test acc  0.6673, time 32.0 sec
# epoch 148, loss 0.312498, train acc 0.862277, sy19 test acc  0.7608, sy20 test acc  0.7154, time 32.1 sec
# epoch 149, loss 0.311473, train acc 0.863914, sy19 test acc  0.8105, sy20 test acc  0.6672, time 32.0 sec
# epoch 150, loss 0.308269, train acc 0.864467, sy19 test acc  0.7916, sy20 test acc  0.6799, time 32.0 sec
# epoch 151, loss 0.305481, train acc 0.869330, sy19 test acc  0.8122, sy20 test acc  0.6663, time 32.0 sec
# epoch 152, loss 0.301988, train acc 0.867274, sy19 test acc  0.8396, sy20 test acc  0.6346, time 32.0 sec
# epoch 153, loss 0.298814, train acc 0.870430, sy19 test acc  0.7947, sy20 test acc  0.6876, time 32.0 sec
# epoch 154, loss 0.301093, train acc 0.867773, sy19 test acc  0.7653, sy20 test acc  0.6876, time 32.1 sec
# epoch 155, loss 0.296934, train acc 0.869172, sy19 test acc  0.8301, sy20 test acc  0.6455, time 32.0 sec
# epoch 156, loss 0.289278, train acc 0.875395, sy19 test acc  0.7845, sy20 test acc  0.6865, time 32.0 sec
# epoch 157, loss 0.293381, train acc 0.873134, sy19 test acc  0.8359, sy20 test acc  0.6209, time 32.0 sec
# epoch 158, loss 0.292096, train acc 0.873482, sy19 test acc  0.7901, sy20 test acc  0.6702, time 32.1 sec
# epoch 159, loss 0.291820, train acc 0.873482, sy19 test acc  0.7905, sy20 test acc  0.6800, time 32.1 sec
# epoch 160, loss 0.285843, train acc 0.879191, sy19 test acc  0.8166, sy20 test acc  0.6527, time 32.0 sec
# epoch 161, loss 0.282373, train acc 0.883200, sy19 test acc  0.7738, sy20 test acc  0.7005, time 32.0 sec
# epoch 162, loss 0.287873, train acc 0.877388, sy19 test acc  0.7825, sy20 test acc  0.6944, time 32.0 sec
# epoch 163, loss 0.282275, train acc 0.879594, sy19 test acc  0.8283, sy20 test acc  0.6388, time 32.1 sec
# epoch 164, loss 0.279623, train acc 0.880195, sy19 test acc  0.7549, sy20 test acc  0.7093, time 32.1 sec
# epoch 165, loss 0.277688, train acc 0.886505, sy19 test acc  0.7883, sy20 test acc  0.6724, time 32.0 sec
# epoch 166, loss 0.276893, train acc 0.882907, sy19 test acc  0.8075, sy20 test acc  0.6644, time 32.0 sec
# epoch 167, loss 0.270435, train acc 0.887312, sy19 test acc  0.8188, sy20 test acc  0.6520, time 32.1 sec
# epoch 168, loss 0.266840, train acc 0.889162, sy19 test acc  0.8096, sy20 test acc  0.6587, time 32.1 sec
# epoch 169, loss 0.267142, train acc 0.888316, sy19 test acc  0.8014, sy20 test acc  0.6802, time 32.0 sec
# epoch 170, loss 0.270539, train acc 0.885050, sy19 test acc  0.8188, sy20 test acc  0.6548, time 32.1 sec
# epoch 171, loss 0.272488, train acc 0.881895, sy19 test acc  0.8118, sy20 test acc  0.6729, time 32.1 sec
# epoch 172, loss 0.265809, train acc 0.892966, sy19 test acc  0.7997, sy20 test acc  0.6772, time 32.1 sec
# epoch 173, loss 0.257090, train acc 0.894966, sy19 test acc  0.8120, sy20 test acc  0.6622, time 32.1 sec
# epoch 174, loss 0.261020, train acc 0.893321, sy19 test acc  0.8031, sy20 test acc  0.6685, time 32.0 sec
# epoch 175, loss 0.260629, train acc 0.892871, sy19 test acc  0.8194, sy20 test acc  0.6578, time 32.1 sec
# epoch 176, loss 0.257708, train acc 0.894318, sy19 test acc  0.7864, sy20 test acc  0.6760, time 32.0 sec
# epoch 177, loss 0.251733, train acc 0.898683, sy19 test acc  0.8032, sy20 test acc  0.6721, time 32.1 sec
# epoch 178, loss 0.255237, train acc 0.895725, sy19 test acc  0.8201, sy20 test acc  0.6551, time 32.0 sec
# epoch 179, loss 0.247427, train acc 0.898983, sy19 test acc  0.7773, sy20 test acc  0.6861, time 32.0 sec
# epoch 180, loss 0.251839, train acc 0.897323, sy19 test acc  0.7758, sy20 test acc  0.6962, time 32.0 sec
# epoch 181, loss 0.245772, train acc 0.897473, sy19 test acc  0.8010, sy20 test acc  0.6810, time 32.1 sec
# epoch 182, loss 0.242376, train acc 0.902889, sy19 test acc  0.8014, sy20 test acc  0.6607, time 32.1 sec
# epoch 183, loss 0.242179, train acc 0.901332, sy19 test acc  0.7599, sy20 test acc  0.6999, time 32.1 sec
# epoch 184, loss 0.240136, train acc 0.902984, sy19 test acc  0.7760, sy20 test acc  0.6824, time 32.0 sec
# epoch 185, loss 0.235600, train acc 0.905143, sy19 test acc  0.8544, sy20 test acc  0.6032, time 32.0 sec
# epoch 186, loss 0.234742, train acc 0.906195, sy19 test acc  0.8027, sy20 test acc  0.6667, time 32.0 sec
# epoch 187, loss 0.230506, train acc 0.905791, sy19 test acc  0.8072, sy20 test acc  0.6513, time 32.0 sec
# epoch 188, loss 0.230441, train acc 0.910101, sy19 test acc  0.8164, sy20 test acc  0.6554, time 32.0 sec
# epoch 189, loss 0.229253, train acc 0.908591, sy19 test acc  0.8072, sy20 test acc  0.6629, time 32.0 sec
# epoch 190, loss 0.221873, train acc 0.912592, sy19 test acc  0.7964, sy20 test acc  0.6765, time 32.0 sec
# epoch 191, loss 0.225465, train acc 0.906139, sy19 test acc  0.8118, sy20 test acc  0.6550, time 32.0 sec
# epoch 192, loss 0.223317, train acc 0.910647, sy19 test acc  0.8277, sy20 test acc  0.6342, time 32.1 sec
# epoch 193, loss 0.221670, train acc 0.911809, sy19 test acc  0.8066, sy20 test acc  0.6579, time 32.0 sec
# epoch 194, loss 0.218330, train acc 0.911793, sy19 test acc  0.7962, sy20 test acc  0.6701, time 32.0 sec
# epoch 195, loss 0.220682, train acc 0.911698, sy19 test acc  0.8307, sy20 test acc  0.6421, time 32.0 sec
# epoch 196, loss 0.222178, train acc 0.912402, sy19 test acc  0.8079, sy20 test acc  0.6550, time 32.0 sec
# epoch 197, loss 0.212569, train acc 0.915707, sy19 test acc  0.7905, sy20 test acc  0.6701, time 32.1 sec
# epoch 198, loss 0.212921, train acc 0.916103, sy19 test acc  0.7942, sy20 test acc  0.6694, time 32.0 sec
# epoch 199, loss 0.211358, train acc 0.916205, sy19 test acc  0.7766, sy20 test acc  0.6610, time 32.0 sec
# epoch 200, loss 0.205205, train acc 0.919851, sy19 test acc  0.8172, sy20 test acc  0.6496, time 32.0 sec
# epoch 201, loss 0.206918, train acc 0.918317, sy19 test acc  0.8285, sy20 test acc  0.6398, time 32.1 sec
# epoch 202, loss 0.204486, train acc 0.915502, sy19 test acc  0.8329, sy20 test acc  0.6253, time 32.0 sec
# epoch 203, loss 0.201635, train acc 0.919463, sy19 test acc  0.7519, sy20 test acc  0.7065, time 32.1 sec
# epoch 204, loss 0.205666, train acc 0.918008, sy19 test acc  0.8339, sy20 test acc  0.6228, time 32.1 sec
# epoch 205, loss 0.194264, train acc 0.924421, sy19 test acc  0.7890, sy20 test acc  0.6669, time 32.1 sec
# epoch 206, loss 0.194087, train acc 0.923124, sy19 test acc  0.8181, sy20 test acc  0.6555, time 32.0 sec
# epoch 207, loss 0.202858, train acc 0.915960, sy19 test acc  0.8266, sy20 test acc  0.6338, time 32.1 sec
# epoch 208, loss 0.193506, train acc 0.923314, sy19 test acc  0.7992, sy20 test acc  0.6545, time 32.1 sec
# epoch 209, loss 0.193593, train acc 0.925172, sy19 test acc  0.8192, sy20 test acc  0.6477, time 32.1 sec
# epoch 210, loss 0.192022, train acc 0.923820, sy19 test acc  0.8244, sy20 test acc  0.6283, time 32.2 sec
# epoch 211, loss 0.184748, train acc 0.929134, sy19 test acc  0.8062, sy20 test acc  0.6508, time 32.1 sec
# epoch 212, loss 0.187469, train acc 0.927924, sy19 test acc  0.7971, sy20 test acc  0.6720, time 32.2 sec
# epoch 213, loss 0.182692, train acc 0.927980, sy19 test acc  0.8294, sy20 test acc  0.6279, time 32.1 sec
# epoch 214, loss 0.175751, train acc 0.934630, sy19 test acc  0.7912, sy20 test acc  0.6822, time 32.1 sec
# epoch 215, loss 0.188820, train acc 0.928327, sy19 test acc  0.7879, sy20 test acc  0.6834, time 32.1 sec
# epoch 216, loss 0.181672, train acc 0.929624, sy19 test acc  0.8194, sy20 test acc  0.6429, time 32.1 sec
# epoch 217, loss 0.174428, train acc 0.933839, sy19 test acc  0.8066, sy20 test acc  0.6466, time 32.0 sec
# epoch 218, loss 0.174422, train acc 0.933436, sy19 test acc  0.7805, sy20 test acc  0.6652, time 32.1 sec
# epoch 219, loss 0.177199, train acc 0.929933, sy19 test acc  0.7645, sy20 test acc  0.6834, time 32.1 sec
# epoch 220, loss 0.176228, train acc 0.927924, sy19 test acc  0.8344, sy20 test acc  0.6108, time 32.0 sec
# epoch 221, loss 0.171433, train acc 0.933784, sy19 test acc  0.8322, sy20 test acc  0.6289, time 32.1 sec
# epoch 222, loss 0.163702, train acc 0.938299, sy19 test acc  0.8187, sy20 test acc  0.6458, time 32.0 sec
# epoch 223, loss 0.166110, train acc 0.933040, sy19 test acc  0.8578, sy20 test acc  0.5988, time 32.0 sec
# epoch 224, loss 0.172970, train acc 0.933388, sy19 test acc  0.7662, sy20 test acc  0.6954, time 32.1 sec
# epoch 225, loss 0.175271, train acc 0.933784, sy19 test acc  0.8131, sy20 test acc  0.6377, time 32.0 sec
# epoch 226, loss 0.166718, train acc 0.936939, sy19 test acc  0.7899, sy20 test acc  0.6651, time 31.9 sec
# epoch 227, loss 0.162183, train acc 0.939097, sy19 test acc  0.7903, sy20 test acc  0.6687, time 31.9 sec
# epoch 228, loss 0.165861, train acc 0.934582, sy19 test acc  0.8502, sy20 test acc  0.5807, time 32.0 sec
# epoch 229, loss 0.161687, train acc 0.936946, sy19 test acc  0.7870, sy20 test acc  0.6538, time 32.0 sec
# epoch 230, loss 0.158841, train acc 0.939453, sy19 test acc  0.8339, sy20 test acc  0.6208, time 32.0 sec
# epoch 231, loss 0.154734, train acc 0.942347, sy19 test acc  0.8374, sy20 test acc  0.6262, time 32.0 sec
# epoch 232, loss 0.150036, train acc 0.942743, sy19 test acc  0.8396, sy20 test acc  0.6081, time 32.0 sec
# epoch 233, loss 0.153741, train acc 0.941794, sy19 test acc  0.8168, sy20 test acc  0.6376, time 32.0 sec
# epoch 234, loss 0.152131, train acc 0.940094, sy19 test acc  0.7860, sy20 test acc  0.6737, time 32.1 sec
# epoch 235, loss 0.149434, train acc 0.943257, sy19 test acc  0.8006, sy20 test acc  0.6616, time 32.1 sec
# epoch 236, loss 0.149406, train acc 0.941999, sy19 test acc  0.8175, sy20 test acc  0.6232, time 32.0 sec
# epoch 237, loss 0.144539, train acc 0.947614, sy19 test acc  0.8259, sy20 test acc  0.6249, time 32.0 sec
# epoch 238, loss 0.147290, train acc 0.946111, sy19 test acc  0.8077, sy20 test acc  0.6515, time 32.0 sec
# epoch 239, loss 0.139854, train acc 0.946514, sy19 test acc  0.8105, sy20 test acc  0.6471, time 32.0 sec
# epoch 240, loss 0.156077, train acc 0.940299, sy19 test acc  0.8622, sy20 test acc  0.5721, time 32.0 sec
# epoch 241, loss 0.152871, train acc 0.941153, sy19 test acc  0.7927, sy20 test acc  0.6698, time 32.0 sec
# epoch 242, loss 0.139830, train acc 0.947052, sy19 test acc  0.8148, sy20 test acc  0.6311, time 32.0 sec
# epoch 243, loss 0.142441, train acc 0.947013, sy19 test acc  0.8320, sy20 test acc  0.6146, time 32.0 sec
# epoch 244, loss 0.134071, train acc 0.949614, sy19 test acc  0.8042, sy20 test acc  0.6462, time 32.0 sec
# epoch 245, loss 0.137609, train acc 0.948017, sy19 test acc  0.7614, sy20 test acc  0.7006, time 32.0 sec
# epoch 246, loss 0.137865, train acc 0.947511, sy19 test acc  0.8105, sy20 test acc  0.6259, time 32.1 sec
# epoch 247, loss 0.129458, train acc 0.952018, sy19 test acc  0.8185, sy20 test acc  0.6199, time 32.0 sec
# epoch 248, loss 0.129679, train acc 0.951923, sy19 test acc  0.8261, sy20 test acc  0.6212, time 32.0 sec
# epoch 249, loss 0.127154, train acc 0.954066, sy19 test acc  0.8122, sy20 test acc  0.6447, time 32.0 sec
# epoch 250, loss 0.126847, train acc 0.954675, sy19 test acc  0.8181, sy20 test acc  0.6282, time 32.0 sec
# epoch 251, loss 0.126527, train acc 0.952919, sy19 test acc  0.8016, sy20 test acc  0.6409, time 32.0 sec
# epoch 252, loss 0.132188, train acc 0.950263, sy19 test acc  0.8129, sy20 test acc  0.6259, time 32.0 sec
# epoch 253, loss 0.124863, train acc 0.955521, sy19 test acc  0.7777, sy20 test acc  0.6777, time 32.0 sec
# epoch 254, loss 0.126138, train acc 0.953323, sy19 test acc  0.8114, sy20 test acc  0.6349, time 32.0 sec
# epoch 255, loss 0.127062, train acc 0.955379, sy19 test acc  0.8354, sy20 test acc  0.6061, time 32.0 sec
# epoch 256, loss 0.127617, train acc 0.951717, sy19 test acc  0.8083, sy20 test acc  0.6310, time 32.0 sec
# epoch 257, loss 0.120995, train acc 0.955821, sy19 test acc  0.8151, sy20 test acc  0.6326, time 32.0 sec
# epoch 258, loss 0.121378, train acc 0.954770, sy19 test acc  0.8372, sy20 test acc  0.6126, time 32.0 sec
# epoch 259, loss 0.126375, train acc 0.952912, sy19 test acc  0.8585, sy20 test acc  0.5879, time 32.0 sec
# epoch 260, loss 0.118935, train acc 0.958178, sy19 test acc  0.7990, sy20 test acc  0.6567, time 32.0 sec
# epoch 261, loss 0.127785, train acc 0.954121, sy19 test acc  0.8318, sy20 test acc  0.6233, time 32.0 sec
# epoch 262, loss 0.114731, train acc 0.959981, sy19 test acc  0.8151, sy20 test acc  0.6321, time 32.0 sec
# epoch 263, loss 0.115525, train acc 0.958779, sy19 test acc  0.7986, sy20 test acc  0.6395, time 32.0 sec
# epoch 264, loss 0.112761, train acc 0.960431, sy19 test acc  0.8165, sy20 test acc  0.5994, time 32.0 sec
# epoch 265, loss 0.114990, train acc 0.957830, sy19 test acc  0.8440, sy20 test acc  0.6072, time 32.0 sec
# epoch 266, loss 0.113383, train acc 0.960084, sy19 test acc  0.8442, sy20 test acc  0.6148, time 32.0 sec
# epoch 267, loss 0.110965, train acc 0.959182, sy19 test acc  0.8277, sy20 test acc  0.6214, time 32.0 sec
# epoch 268, loss 0.111621, train acc 0.958621, sy19 test acc  0.8142, sy20 test acc  0.6318, time 32.0 sec
# epoch 269, loss 0.110872, train acc 0.960732, sy19 test acc  0.7812, sy20 test acc  0.6689, time 32.0 sec
# epoch 270, loss 0.107135, train acc 0.960938, sy19 test acc  0.7853, sy20 test acc  0.6532, time 32.0 sec
# epoch 271, loss 0.101968, train acc 0.961728, sy19 test acc  0.8235, sy20 test acc  0.6260, time 32.0 sec
# epoch 272, loss 0.110033, train acc 0.960131, sy19 test acc  0.8177, sy20 test acc  0.6244, time 32.0 sec
# epoch 273, loss 0.105464, train acc 0.963982, sy19 test acc  0.8138, sy20 test acc  0.6207, time 32.0 sec
# epoch 274, loss 0.102664, train acc 0.961839, sy19 test acc  0.8107, sy20 test acc  0.6213, time 32.1 sec
# epoch 275, loss 0.100896, train acc 0.962337, sy19 test acc  0.8342, sy20 test acc  0.6110, time 32.0 sec
# epoch 276, loss 0.104541, train acc 0.962037, sy19 test acc  0.8151, sy20 test acc  0.6351, time 32.0 sec
# epoch 277, loss 0.101420, train acc 0.963737, sy19 test acc  0.8192, sy20 test acc  0.6221, time 32.0 sec
# epoch 278, loss 0.097229, train acc 0.963942, sy19 test acc  0.8113, sy20 test acc  0.6333, time 32.0 sec
# epoch 279, loss 0.100288, train acc 0.964440, sy19 test acc  0.8192, sy20 test acc  0.6378, time 32.0 sec
# epoch 280, loss 0.099631, train acc 0.961483, sy19 test acc  0.8077, sy20 test acc  0.6405, time 32.0 sec
# epoch 281, loss 0.101544, train acc 0.963333, sy19 test acc  0.8038, sy20 test acc  0.6397, time 32.0 sec
# epoch 282, loss 0.097090, train acc 0.966243, sy19 test acc  0.8411, sy20 test acc  0.6004, time 32.1 sec
# epoch 283, loss 0.099337, train acc 0.965840, sy19 test acc  0.8376, sy20 test acc  0.6071, time 32.0 sec
# epoch 284, loss 0.094258, train acc 0.964338, sy19 test acc  0.7783, sy20 test acc  0.6576, time 32.0 sec
# epoch 285, loss 0.091050, train acc 0.968347, sy19 test acc  0.8120, sy20 test acc  0.6382, time 32.0 sec
# epoch 286, loss 0.094167, train acc 0.966141, sy19 test acc  0.8489, sy20 test acc  0.5751, time 32.0 sec
# epoch 287, loss 0.095058, train acc 0.965793, sy19 test acc  0.8270, sy20 test acc  0.6181, time 32.1 sec
# epoch 288, loss 0.088702, train acc 0.969746, sy19 test acc  0.8100, sy20 test acc  0.6331, time 32.1 sec
# epoch 289, loss 0.089348, train acc 0.969098, sy19 test acc  0.7859, sy20 test acc  0.6456, time 32.0 sec
# epoch 290, loss 0.090735, train acc 0.968299, sy19 test acc  0.7769, sy20 test acc  0.6709, time 32.0 sec
# epoch 291, loss 0.093351, train acc 0.966544, sy19 test acc  0.8216, sy20 test acc  0.6307, time 32.0 sec
# epoch 292, loss 0.095622, train acc 0.961989, sy19 test acc  0.8442, sy20 test acc  0.6013, time 32.0 sec
# epoch 293, loss 0.093003, train acc 0.966188, sy19 test acc  0.8278, sy20 test acc  0.5995, time 32.0 sec
# epoch 294, loss 0.093952, train acc 0.964788, sy19 test acc  0.8112, sy20 test acc  0.6383, time 32.0 sec
# epoch 295, loss 0.087927, train acc 0.965785, sy19 test acc  0.8444, sy20 test acc  0.6046, time 32.0 sec
# epoch 296, loss 0.085001, train acc 0.970751, sy19 test acc  0.8205, sy20 test acc  0.6228, time 32.0 sec
# epoch 297, loss 0.089999, train acc 0.967042, sy19 test acc  0.8418, sy20 test acc  0.6020, time 32.0 sec
# epoch 298, loss 0.080159, train acc 0.972000, sy19 test acc  0.8452, sy20 test acc  0.5845, time 32.0 sec
# epoch 299, loss 0.086104, train acc 0.971597, sy19 test acc  0.8166, sy20 test acc  0.6176, time 32.0 sec
# epoch 300, loss 0.089030, train acc 0.967445, sy19 test acc  0.8203, sy20 test acc  0.6478, time 32.1 sec
# epoch 301, loss 0.088153, train acc 0.966496, sy19 test acc  0.8329, sy20 test acc  0.6168, time 32.0 sec
# epoch 302, loss 0.085322, train acc 0.970600, sy19 test acc  0.8329, sy20 test acc  0.6233, time 32.0 sec
# epoch 303, loss 0.081300, train acc 0.971446, sy19 test acc  0.7936, sy20 test acc  0.6418, time 32.0 sec
# epoch 304, loss 0.083234, train acc 0.969398, sy19 test acc  0.7779, sy20 test acc  0.6652, time 32.0 sec
# epoch 305, loss 0.086386, train acc 0.968845, sy19 test acc  0.8268, sy20 test acc  0.6092, time 32.1 sec
# epoch 306, loss 0.080437, train acc 0.971304, sy19 test acc  0.7964, sy20 test acc  0.6429, time 32.1 sec
# epoch 307, loss 0.078253, train acc 0.970751, sy19 test acc  0.7944, sy20 test acc  0.6509, time 32.0 sec
# epoch 308, loss 0.075222, train acc 0.976262, sy19 test acc  0.7940, sy20 test acc  0.6457, time 32.0 sec
# epoch 309, loss 0.077116, train acc 0.972806, sy19 test acc  0.8287, sy20 test acc  0.6058, time 32.1 sec
# epoch 310, loss 0.076530, train acc 0.972601, sy19 test acc  0.8153, sy20 test acc  0.6219, time 32.2 sec
# epoch 311, loss 0.072173, train acc 0.976262, sy19 test acc  0.8511, sy20 test acc  0.5854, time 32.0 sec
# epoch 312, loss 0.083003, train acc 0.969351, sy19 test acc  0.8244, sy20 test acc  0.6190, time 32.1 sec
# epoch 313, loss 0.079965, train acc 0.971098, sy19 test acc  0.8298, sy20 test acc  0.6115, time 32.1 sec
# epoch 314, loss 0.072269, train acc 0.974206, sy19 test acc  0.8320, sy20 test acc  0.6067, time 32.1 sec
# epoch 315, loss 0.077995, train acc 0.973004, sy19 test acc  0.8422, sy20 test acc  0.6054, time 32.3 sec
# epoch 316, loss 0.074488, train acc 0.971905, sy19 test acc  0.7862, sy20 test acc  0.6511, time 32.2 sec
# epoch 317, loss 0.078647, train acc 0.971344, sy19 test acc  0.8320, sy20 test acc  0.6136, time 32.0 sec
# epoch 318, loss 0.075582, train acc 0.973597, sy19 test acc  0.8348, sy20 test acc  0.6069, time 32.0 sec
# epoch 319, loss 0.068031, train acc 0.977962, sy19 test acc  0.8530, sy20 test acc  0.5829, time 32.1 sec
# epoch 320, loss 0.076597, train acc 0.974957, sy19 test acc  0.8442, sy20 test acc  0.5932, time 32.0 sec
# epoch 321, loss 0.075604, train acc 0.974206, sy19 test acc  0.8146, sy20 test acc  0.6283, time 32.1 sec
# epoch 322, loss 0.071395, train acc 0.974657, sy19 test acc  0.8259, sy20 test acc  0.6039, time 32.1 sec
# epoch 323, loss 0.078664, train acc 0.969596, sy19 test acc  0.8251, sy20 test acc  0.6228, time 32.1 sec
# epoch 324, loss 0.074137, train acc 0.973052, sy19 test acc  0.8203, sy20 test acc  0.6230, time 32.1 sec
# epoch 325, loss 0.065629, train acc 0.979061, sy19 test acc  0.8511, sy20 test acc  0.5797, time 32.0 sec
# epoch 326, loss 0.066583, train acc 0.975108, sy19 test acc  0.8350, sy20 test acc  0.6064, time 32.0 sec
# epoch 327, loss 0.065691, train acc 0.976412, sy19 test acc  0.8151, sy20 test acc  0.6220, time 32.0 sec
# epoch 328, loss 0.070775, train acc 0.974554, sy19 test acc  0.8315, sy20 test acc  0.6086, time 32.1 sec
# epoch 329, loss 0.072716, train acc 0.975859, sy19 test acc  0.8318, sy20 test acc  0.6213, time 32.0 sec
# epoch 330, loss 0.078672, train acc 0.971154, sy19 test acc  0.8057, sy20 test acc  0.6426, time 32.0 sec
# epoch 331, loss 0.066869, train acc 0.977662, sy19 test acc  0.8203, sy20 test acc  0.6203, time 32.0 sec
# epoch 332, loss 0.062244, train acc 0.979765, sy19 test acc  0.8396, sy20 test acc  0.5911, time 32.0 sec
# epoch 333, loss 0.061109, train acc 0.979465, sy19 test acc  0.8368, sy20 test acc  0.6177, time 32.0 sec
# epoch 334, loss 0.072258, train acc 0.972696, sy19 test acc  0.8100, sy20 test acc  0.6168, time 32.0 sec
# epoch 335, loss 0.061683, train acc 0.978413, sy19 test acc  0.8405, sy20 test acc  0.5978, time 32.0 sec
# epoch 336, loss 0.074492, train acc 0.972854, sy19 test acc  0.8105, sy20 test acc  0.6355, time 32.0 sec
# epoch 337, loss 0.074728, train acc 0.972000, sy19 test acc  0.8457, sy20 test acc  0.5880, time 32.0 sec
# epoch 338, loss 0.062939, train acc 0.977211, sy19 test acc  0.8185, sy20 test acc  0.6181, time 32.0 sec
# epoch 339, loss 0.065719, train acc 0.976760, sy19 test acc  0.7809, sy20 test acc  0.6522, time 32.0 sec
# epoch 340, loss 0.063480, train acc 0.977511, sy19 test acc  0.8257, sy20 test acc  0.6234, time 32.0 sec
# epoch 341, loss 0.065036, train acc 0.977464, sy19 test acc  0.7903, sy20 test acc  0.6463, time 32.0 sec
# epoch 342, loss 0.060956, train acc 0.980263, sy19 test acc  0.7892, sy20 test acc  0.6592, time 32.0 sec
# epoch 343, loss 0.061878, train acc 0.978816, sy19 test acc  0.8001, sy20 test acc  0.6473, time 32.0 sec
# epoch 344, loss 0.072037, train acc 0.973906, sy19 test acc  0.8001, sy20 test acc  0.6464, time 32.0 sec
# epoch 345, loss 0.062036, train acc 0.979417, sy19 test acc  0.8042, sy20 test acc  0.6324, time 32.0 sec
# epoch 346, loss 0.059418, train acc 0.980864, sy19 test acc  0.8407, sy20 test acc  0.5990, time 32.0 sec
# epoch 347, loss 0.061279, train acc 0.977511, sy19 test acc  0.8379, sy20 test acc  0.6196, time 32.0 sec
# epoch 348, loss 0.062318, train acc 0.978065, sy19 test acc  0.8079, sy20 test acc  0.6286, time 32.0 sec
# epoch 349, loss 0.070107, train acc 0.977013, sy19 test acc  0.8179, sy20 test acc  0.6186, time 32.0 sec
# epoch 350, loss 0.058615, train acc 0.979164, sy19 test acc  0.8040, sy20 test acc  0.6381, time 32.0 sec
# epoch 351, loss 0.060781, train acc 0.978864, sy19 test acc  0.8164, sy20 test acc  0.6262, time 32.0 sec
# epoch 352, loss 0.065098, train acc 0.976760, sy19 test acc  0.8398, sy20 test acc  0.6065, time 32.0 sec
# epoch 353, loss 0.051490, train acc 0.982517, sy19 test acc  0.8396, sy20 test acc  0.5894, time 32.0 sec
# epoch 354, loss 0.054744, train acc 0.981418, sy19 test acc  0.8172, sy20 test acc  0.6316, time 32.0 sec
# epoch 355, loss 0.056348, train acc 0.980967, sy19 test acc  0.8214, sy20 test acc  0.6263, time 32.0 sec
# epoch 356, loss 0.059953, train acc 0.978413, sy19 test acc  0.8580, sy20 test acc  0.5886, time 32.0 sec
# epoch 357, loss 0.050700, train acc 0.982319, sy19 test acc  0.8335, sy20 test acc  0.6028, time 32.0 sec
# epoch 358, loss 0.052430, train acc 0.982319, sy19 test acc  0.8209, sy20 test acc  0.6283, time 32.0 sec
# epoch 359, loss 0.050978, train acc 0.983821, sy19 test acc  0.8005, sy20 test acc  0.6519, time 32.0 sec
# epoch 360, loss 0.051177, train acc 0.980817, sy19 test acc  0.8325, sy20 test acc  0.6296, time 32.0 sec
# epoch 361, loss 0.051401, train acc 0.982121, sy19 test acc  0.8100, sy20 test acc  0.6320, time 32.0 sec
# epoch 362, loss 0.057299, train acc 0.979868, sy19 test acc  0.7866, sy20 test acc  0.6539, time 32.0 sec
# epoch 363, loss 0.063254, train acc 0.977314, sy19 test acc  0.7905, sy20 test acc  0.6433, time 32.0 sec
# epoch 364, loss 0.052237, train acc 0.982121, sy19 test acc  0.8342, sy20 test acc  0.6044, time 32.0 sec
# epoch 365, loss 0.054130, train acc 0.982019, sy19 test acc  0.8227, sy20 test acc  0.6261, time 32.0 sec
# epoch 366, loss 0.052466, train acc 0.982572, sy19 test acc  0.7992, sy20 test acc  0.6494, time 32.0 sec
# epoch 367, loss 0.059064, train acc 0.980714, sy19 test acc  0.8355, sy20 test acc  0.6131, time 32.0 sec
# epoch 368, loss 0.058807, train acc 0.981718, sy19 test acc  0.8159, sy20 test acc  0.6378, time 32.0 sec
# epoch 369, loss 0.055873, train acc 0.979109, sy19 test acc  0.8500, sy20 test acc  0.5954, time 32.0 sec
# epoch 370, loss 0.060925, train acc 0.976958, sy19 test acc  0.8118, sy20 test acc  0.6365, time 32.0 sec
# epoch 371, loss 0.054563, train acc 0.980516, sy19 test acc  0.8324, sy20 test acc  0.5980, time 32.0 sec
# epoch 372, loss 0.054338, train acc 0.978713, sy19 test acc  0.8151, sy20 test acc  0.6269, time 32.0 sec
# epoch 373, loss 0.055662, train acc 0.981117, sy19 test acc  0.8131, sy20 test acc  0.6330, time 32.0 sec
# epoch 374, loss 0.049654, train acc 0.982920, sy19 test acc  0.8366, sy20 test acc  0.6031, time 32.0 sec
# epoch 375, loss 0.059673, train acc 0.978713, sy19 test acc  0.8075, sy20 test acc  0.6379, time 32.0 sec
# epoch 376, loss 0.052812, train acc 0.981070, sy19 test acc  0.8281, sy20 test acc  0.6088, time 32.0 sec
# epoch 377, loss 0.053108, train acc 0.980919, sy19 test acc  0.8192, sy20 test acc  0.6159, time 32.0 sec
# epoch 378, loss 0.052104, train acc 0.981212, sy19 test acc  0.8381, sy20 test acc  0.5969, time 32.0 sec
# epoch 379, loss 0.046378, train acc 0.983474, sy19 test acc  0.8196, sy20 test acc  0.6232, time 32.0 sec
# epoch 380, loss 0.056145, train acc 0.979868, sy19 test acc  0.8066, sy20 test acc  0.6301, time 32.0 sec
# epoch 381, loss 0.045852, train acc 0.984075, sy19 test acc  0.8142, sy20 test acc  0.6248, time 32.0 sec
# epoch 382, loss 0.044938, train acc 0.983774, sy19 test acc  0.8181, sy20 test acc  0.6141, time 32.0 sec
# epoch 383, loss 0.053593, train acc 0.979117, sy19 test acc  0.8218, sy20 test acc  0.6267, time 32.0 sec
# epoch 384, loss 0.052121, train acc 0.981615, sy19 test acc  0.8344, sy20 test acc  0.5994, time 32.0 sec
# epoch 385, loss 0.053462, train acc 0.981117, sy19 test acc  0.8268, sy20 test acc  0.6208, time 32.0 sec
# epoch 386, loss 0.050642, train acc 0.982169, sy19 test acc  0.8289, sy20 test acc  0.6121, time 32.0 sec
# epoch 387, loss 0.053868, train acc 0.980714, sy19 test acc  0.8307, sy20 test acc  0.6135, time 32.0 sec
# epoch 388, loss 0.045512, train acc 0.984525, sy19 test acc  0.8374, sy20 test acc  0.6029, time 32.0 sec
# epoch 389, loss 0.041926, train acc 0.987427, sy19 test acc  0.8327, sy20 test acc  0.6094, time 32.0 sec
# epoch 390, loss 0.048211, train acc 0.982620, sy19 test acc  0.8109, sy20 test acc  0.6364, time 32.0 sec
# epoch 391, loss 0.046950, train acc 0.983972, sy19 test acc  0.8038, sy20 test acc  0.6213, time 32.0 sec
# epoch 392, loss 0.041962, train acc 0.986376, sy19 test acc  0.8120, sy20 test acc  0.6354, time 32.0 sec
# epoch 393, loss 0.044877, train acc 0.982572, sy19 test acc  0.8294, sy20 test acc  0.5885, time 32.0 sec
# epoch 394, loss 0.051455, train acc 0.982572, sy19 test acc  0.8433, sy20 test acc  0.6083, time 32.0 sec
# epoch 395, loss 0.046559, train acc 0.985522, sy19 test acc  0.8100, sy20 test acc  0.6301, time 32.0 sec
# epoch 396, loss 0.054561, train acc 0.980413, sy19 test acc  0.8485, sy20 test acc  0.5895, time 32.0 sec
# epoch 397, loss 0.049239, train acc 0.982572, sy19 test acc  0.8153, sy20 test acc  0.6199, time 32.0 sec
# epoch 398, loss 0.049326, train acc 0.982469, sy19 test acc  0.8018, sy20 test acc  0.6364, time 32.0 sec
# epoch 399, loss 0.042292, train acc 0.984525, sy19 test acc  0.8270, sy20 test acc  0.6096, time 32.0 sec
# epoch 400, loss 0.045504, train acc 0.984075, sy19 test acc  0.8390, sy20 test acc  0.6017, time 32.0 sec
# epoch 401, loss 0.044273, train acc 0.985023, sy19 test acc  0.8359, sy20 test acc  0.5901, time 32.0 sec
# epoch 402, loss 0.043003, train acc 0.984525, sy19 test acc  0.8227, sy20 test acc  0.6161, time 32.0 sec
# epoch 403, loss 0.048237, train acc 0.983521, sy19 test acc  0.8263, sy20 test acc  0.6086, time 32.0 sec
# epoch 404, loss 0.044681, train acc 0.984826, sy19 test acc  0.8396, sy20 test acc  0.6067, time 32.0 sec
# epoch 405, loss 0.054796, train acc 0.980714, sy19 test acc  0.8396, sy20 test acc  0.5982, time 32.0 sec
# epoch 406, loss 0.046117, train acc 0.983774, sy19 test acc  0.8448, sy20 test acc  0.5803, time 32.0 sec
# epoch 407, loss 0.044309, train acc 0.984272, sy19 test acc  0.8124, sy20 test acc  0.6347, time 32.0 sec
# epoch 408, loss 0.046173, train acc 0.984422, sy19 test acc  0.8337, sy20 test acc  0.6057, time 32.0 sec
# epoch 409, loss 0.048204, train acc 0.983173, sy19 test acc  0.8363, sy20 test acc  0.6083, time 32.0 sec
# epoch 410, loss 0.045824, train acc 0.984075, sy19 test acc  0.8719, sy20 test acc  0.5626, time 32.0 sec
# epoch 411, loss 0.047481, train acc 0.983869, sy19 test acc  0.8088, sy20 test acc  0.6320, time 32.0 sec
# epoch 412, loss 0.039452, train acc 0.989032, sy19 test acc  0.8233, sy20 test acc  0.6164, time 32.0 sec
# epoch 413, loss 0.040406, train acc 0.984723, sy19 test acc  0.8392, sy20 test acc  0.6031, time 32.0 sec
# epoch 414, loss 0.043438, train acc 0.985023, sy19 test acc  0.8153, sy20 test acc  0.6197, time 32.0 sec
# epoch 415, loss 0.037778, train acc 0.986629, sy19 test acc  0.8277, sy20 test acc  0.6232, time 32.0 sec
# epoch 416, loss 0.046230, train acc 0.984122, sy19 test acc  0.8459, sy20 test acc  0.5879, time 32.0 sec
# epoch 417, loss 0.043093, train acc 0.983774, sy19 test acc  0.8213, sy20 test acc  0.6049, time 32.0 sec
# epoch 418, loss 0.039676, train acc 0.986328, sy19 test acc  0.8270, sy20 test acc  0.6191, time 32.0 sec
# epoch 419, loss 0.039353, train acc 0.987577, sy19 test acc  0.8294, sy20 test acc  0.6103, time 32.0 sec
# epoch 420, loss 0.041048, train acc 0.984422, sy19 test acc  0.8109, sy20 test acc  0.6286, time 32.1 sec
# epoch 421, loss 0.042916, train acc 0.984723, sy19 test acc  0.8151, sy20 test acc  0.6271, time 32.0 sec
# epoch 422, loss 0.040548, train acc 0.986779, sy19 test acc  0.8122, sy20 test acc  0.6348, time 32.0 sec
# epoch 423, loss 0.042076, train acc 0.985324, sy19 test acc  0.8159, sy20 test acc  0.6272, time 32.0 sec
# epoch 424, loss 0.038878, train acc 0.987530, sy19 test acc  0.8294, sy20 test acc  0.6145, time 32.1 sec
# epoch 425, loss 0.040961, train acc 0.985577, sy19 test acc  0.8490, sy20 test acc  0.5858, time 32.0 sec
# epoch 426, loss 0.037007, train acc 0.987380, sy19 test acc  0.8554, sy20 test acc  0.5942, time 32.0 sec
# epoch 427, loss 0.034740, train acc 0.987079, sy19 test acc  0.8331, sy20 test acc  0.6154, time 32.0 sec
# epoch 428, loss 0.041267, train acc 0.985624, sy19 test acc  0.8320, sy20 test acc  0.6086, time 32.0 sec
# epoch 429, loss 0.041996, train acc 0.987728, sy19 test acc  0.8218, sy20 test acc  0.6128, time 32.0 sec
# epoch 430, loss 0.039559, train acc 0.985474, sy19 test acc  0.8235, sy20 test acc  0.6196, time 32.0 sec
# epoch 431, loss 0.038616, train acc 0.988431, sy19 test acc  0.8274, sy20 test acc  0.6135, time 32.0 sec
# epoch 432, loss 0.040941, train acc 0.985877, sy19 test acc  0.8396, sy20 test acc  0.5969, time 32.0 sec
# epoch 433, loss 0.036751, train acc 0.985427, sy19 test acc  0.8326, sy20 test acc  0.5957, time 32.0 sec
# epoch 434, loss 0.039313, train acc 0.986075, sy19 test acc  0.7946, sy20 test acc  0.6419, time 32.0 sec
# epoch 435, loss 0.047843, train acc 0.981821, sy19 test acc  0.8285, sy20 test acc  0.6219, time 32.0 sec
# epoch 436, loss 0.040526, train acc 0.986328, sy19 test acc  0.8148, sy20 test acc  0.6221, time 32.0 sec
# epoch 437, loss 0.039819, train acc 0.985474, sy19 test acc  0.8062, sy20 test acc  0.6406, time 32.0 sec
# epoch 438, loss 0.045820, train acc 0.984573, sy19 test acc  0.8320, sy20 test acc  0.6075, time 32.1 sec
# epoch 439, loss 0.042292, train acc 0.985126, sy19 test acc  0.8031, sy20 test acc  0.6347, time 32.1 sec
# epoch 440, loss 0.038288, train acc 0.988123, sy19 test acc  0.8276, sy20 test acc  0.5996, time 32.0 sec
# epoch 441, loss 0.040620, train acc 0.986629, sy19 test acc  0.8253, sy20 test acc  0.6137, time 32.0 sec
# epoch 442, loss 0.040148, train acc 0.984225, sy19 test acc  0.8337, sy20 test acc  0.6146, time 32.2 sec
# epoch 443, loss 0.041882, train acc 0.985023, sy19 test acc  0.8301, sy20 test acc  0.6152, time 32.0 sec
# epoch 444, loss 0.033534, train acc 0.988131, sy19 test acc  0.8285, sy20 test acc  0.6225, time 32.1 sec
# epoch 445, loss 0.038850, train acc 0.987380, sy19 test acc  0.8572, sy20 test acc  0.5749, time 32.1 sec
# epoch 446, loss 0.039425, train acc 0.985672, sy19 test acc  0.8502, sy20 test acc  0.5831, time 32.0 sec
# epoch 447, loss 0.034739, train acc 0.988882, sy19 test acc  0.8057, sy20 test acc  0.6335, time 32.2 sec
# epoch 448, loss 0.039126, train acc 0.987230, sy19 test acc  0.8320, sy20 test acc  0.6165, time 32.1 sec
# epoch 449, loss 0.037934, train acc 0.986075, sy19 test acc  0.8535, sy20 test acc  0.5894, time 32.1 sec
# epoch 450, loss 0.034741, train acc 0.987230, sy19 test acc  0.8068, sy20 test acc  0.6397, time 32.0 sec
# epoch 451, loss 0.040586, train acc 0.986526, sy19 test acc  0.8229, sy20 test acc  0.6104, time 32.1 sec
# epoch 452, loss 0.038925, train acc 0.988431, sy19 test acc  0.8175, sy20 test acc  0.6095, time 32.1 sec
# epoch 453, loss 0.036862, train acc 0.987530, sy19 test acc  0.8168, sy20 test acc  0.6218, time 32.1 sec
# epoch 454, loss 0.039331, train acc 0.986376, sy19 test acc  0.8468, sy20 test acc  0.5932, time 32.0 sec
# epoch 455, loss 0.040919, train acc 0.986423, sy19 test acc  0.8153, sy20 test acc  0.6351, time 32.1 sec
# epoch 456, loss 0.038692, train acc 0.985877, sy19 test acc  0.8513, sy20 test acc  0.5877, time 32.0 sec
# epoch 457, loss 0.039842, train acc 0.985877, sy19 test acc  0.8279, sy20 test acc  0.6073, time 32.0 sec
# epoch 458, loss 0.035061, train acc 0.987427, sy19 test acc  0.8127, sy20 test acc  0.6413, time 32.0 sec
# epoch 459, loss 0.042302, train acc 0.985126, sy19 test acc  0.8253, sy20 test acc  0.6178, time 32.0 sec
# epoch 460, loss 0.037463, train acc 0.987277, sy19 test acc  0.8096, sy20 test acc  0.6283, time 32.0 sec
# epoch 461, loss 0.036430, train acc 0.987680, sy19 test acc  0.8266, sy20 test acc  0.6172, time 32.0 sec
# epoch 462, loss 0.037871, train acc 0.988131, sy19 test acc  0.8320, sy20 test acc  0.6083, time 32.0 sec
# epoch 463, loss 0.037832, train acc 0.985877, sy19 test acc  0.8339, sy20 test acc  0.5994, time 32.0 sec
# epoch 464, loss 0.040977, train acc 0.984723, sy19 test acc  0.8151, sy20 test acc  0.6201, time 32.0 sec
# epoch 465, loss 0.036081, train acc 0.987380, sy19 test acc  0.8131, sy20 test acc  0.6269, time 32.0 sec
# epoch 466, loss 0.039029, train acc 0.985822, sy19 test acc  0.8283, sy20 test acc  0.6169, time 32.1 sec
# epoch 467, loss 0.030679, train acc 0.990986, sy19 test acc  0.8442, sy20 test acc  0.6048, time 32.0 sec
# epoch 468, loss 0.034970, train acc 0.987680, sy19 test acc  0.8120, sy20 test acc  0.6238, time 32.0 sec
# epoch 469, loss 0.035720, train acc 0.988732, sy19 test acc  0.8157, sy20 test acc  0.6263, time 32.0 sec
# epoch 470, loss 0.036643, train acc 0.986929, sy19 test acc  0.8116, sy20 test acc  0.6322, time 32.0 sec
# epoch 471, loss 0.036857, train acc 0.985624, sy19 test acc  0.8502, sy20 test acc  0.5886, time 32.0 sec
# epoch 472, loss 0.029956, train acc 0.991286, sy19 test acc  0.8209, sy20 test acc  0.6213, time 32.0 sec
# epoch 473, loss 0.032350, train acc 0.989483, sy19 test acc  0.8242, sy20 test acc  0.6262, time 32.0 sec
# epoch 474, loss 0.029751, train acc 0.988930, sy19 test acc  0.8070, sy20 test acc  0.6401, time 32.0 sec
# epoch 475, loss 0.030239, train acc 0.990535, sy19 test acc  0.8274, sy20 test acc  0.6056, time 32.0 sec
# epoch 476, loss 0.032696, train acc 0.988178, sy19 test acc  0.8135, sy20 test acc  0.6192, time 32.0 sec
# epoch 477, loss 0.036850, train acc 0.987380, sy19 test acc  0.8622, sy20 test acc  0.5837, time 32.0 sec
# epoch 478, loss 0.031439, train acc 0.989633, sy19 test acc  0.8166, sy20 test acc  0.6223, time 32.0 sec
# epoch 479, loss 0.033764, train acc 0.987878, sy19 test acc  0.8433, sy20 test acc  0.5921, time 32.0 sec
# epoch 480, loss 0.034383, train acc 0.988131, sy19 test acc  0.8127, sy20 test acc  0.6298, time 32.0 sec
# epoch 481, loss 0.030751, train acc 0.988882, sy19 test acc  0.8175, sy20 test acc  0.6233, time 32.0 sec
# epoch 482, loss 0.030994, train acc 0.990385, sy19 test acc  0.7923, sy20 test acc  0.6449, time 32.0 sec
# epoch 483, loss 0.036539, train acc 0.987277, sy19 test acc  0.8426, sy20 test acc  0.5848, time 32.0 sec
# epoch 484, loss 0.038278, train acc 0.986178, sy19 test acc  0.8489, sy20 test acc  0.5849, time 32.0 sec
# epoch 485, loss 0.038752, train acc 0.986328, sy19 test acc  0.8318, sy20 test acc  0.5984, time 32.0 sec
# epoch 486, loss 0.037606, train acc 0.987530, sy19 test acc  0.8392, sy20 test acc  0.6013, time 32.0 sec
# epoch 487, loss 0.034107, train acc 0.988329, sy19 test acc  0.8348, sy20 test acc  0.5940, time 32.0 sec
# epoch 488, loss 0.034785, train acc 0.986676, sy19 test acc  0.8172, sy20 test acc  0.6208, time 32.0 sec
# epoch 489, loss 0.032970, train acc 0.988629, sy19 test acc  0.8118, sy20 test acc  0.6282, time 32.1 sec
# epoch 490, loss 0.032646, train acc 0.987230, sy19 test acc  0.8639, sy20 test acc  0.5788, time 32.0 sec
# epoch 491, loss 0.034687, train acc 0.986929, sy19 test acc  0.8112, sy20 test acc  0.6309, time 32.0 sec
# epoch 492, loss 0.026733, train acc 0.991436, sy19 test acc  0.8615, sy20 test acc  0.5836, time 32.0 sec
# epoch 493, loss 0.031720, train acc 0.988827, sy19 test acc  0.8089, sy20 test acc  0.6196, time 32.0 sec
# epoch 494, loss 0.034639, train acc 0.987625, sy19 test acc  0.8027, sy20 test acc  0.6490, time 32.0 sec
# epoch 495, loss 0.032405, train acc 0.988779, sy19 test acc  0.8352, sy20 test acc  0.5917, time 32.0 sec
# epoch 496, loss 0.031673, train acc 0.989032, sy19 test acc  0.8385, sy20 test acc  0.5970, time 32.0 sec
# epoch 497, loss 0.029321, train acc 0.989230, sy19 test acc  0.8068, sy20 test acc  0.6398, time 32.0 sec
# epoch 498, loss 0.028969, train acc 0.990582, sy19 test acc  0.8177, sy20 test acc  0.6176, time 32.0 sec
# epoch 499, loss 0.026171, train acc 0.991286, sy19 test acc  0.8315, sy20 test acc  0.6037, time 32.0 sec
# epoch 500, loss 0.034473, train acc 0.984826, sy19 test acc  0.8251, sy20 test acc  0.6216, time 32.0 sec

# %%
## save results
acc_lists = pd.DataFrame({'loss': loss_list, 'train_acc':train_acc_list, 'sy19_test_acc': sy19_test_acc_list, 'sy20_test_acc': sy20_test_acc_list})
acc_lists_filename = 'acc-list-cuda0-'+str(datetime.datetime.now()).replace(' ','-').replace(':','-').replace('.','-')+'.csv'
acc_lists.to_csv('./runs/'+acc_lists_filename)
print(acc_lists_filename)

model_filename = './runs/'+'model-cuda0-'+str(datetime.datetime.now()).replace(' ','-').replace(':','-').replace('.','-')+'.pt'
torch.save(net.state_dict(), 'model_filename')
print(model_filename)

# %%
# save figure
fig = plt.figure(figsize=(8,6))
epoches = np.linspace(1,len(loss_list),len(loss_list))
plt.plot(epoches, train_acc_list, '-', linewidth=1,label='Train Accuracy: Total')
plt.plot(epoches, sy19_test_acc_list, '-', linewidth=1,label='Test Accuracy: Seyfert 1.9')
plt.plot(epoches, sy20_test_acc_list, '-', linewidth=1,label='Test Accuracy: Seyfert 2.0')
plt.plot(epoches, loss_list,'-', linewidth=1,label='Train Loss')


plt.axhline(y=1.0,color='grey',linestyle='solid',linewidth=0.5, alpha=0.5, label='')
plt.axhline(y=0.938,color='green',linestyle='dashed',linewidth=0.5,  label='Accuracy: 93.8%')
plt.axhline(y=0.757,color='orange',linestyle='dashed',linewidth=0.5,  label='Accuracy: 75.7%')
plt.axhline(y=0,color='grey',linestyle='solid',linewidth=0.5,  alpha=0.5, label='')

plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Accuracy & Loss')

#plt.xlim(-1,500)
plt.ylim(-0.02,1.05)

figure_filename = './runs/'+'model-cuda3-'+str(datetime.datetime.now()).replace(' ','-').replace(':','-').replace('.','-')+'.pdf'
fig.tight_layout()
plt.savefig(figure_filename, format='pdf')

# %%
plt.semilogy(epoches, loss_list,label='loss')
plt.legend()
