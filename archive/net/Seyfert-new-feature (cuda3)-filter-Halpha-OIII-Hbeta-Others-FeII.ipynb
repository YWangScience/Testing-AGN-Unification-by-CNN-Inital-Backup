# %% [markdown]
# # Traning for SY 1.9 & 2.0

# %%
import torch
from torch import nn, optim
import torch.nn.functional as F
import time
import os
import datetime
import glob
import csv

import torchvision
from torch.utils.data import DataLoader, TensorDataset, ConcatDataset, random_split
from torchvision import transforms

import pandas as pd
import seaborn as sns

from numpy import genfromtxt

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## define functions

# %%
def plotSpec(seyfert,n):
    if seyfert == 1.9:
        plt.plot(np.linspace(3800,7500,7500-3800+1), sy19_feature[n].tolist())
    if seyfert == 2:
        plt.plot(np.linspace(3800,7500,7500-3800+1), sy2_feature[n].tolist())
        
def plotData(data):
        plt.plot(np.linspace(3800,len(data)-1+3800,len(data)), data.tolist(),linewidth=1)
        
def plotFilters(filters):
    filters = filters.flatten()[1:-1].reshape(-1,2)
    for x in filters:
        plt.axvspan(x[0]+3800, x[1]+3800, alpha=0.5, facecolor='grey')
        
def sizeMap(inputSize):
    IN = inputSize
    C1 = (inputSize-50)+1
    S2 = int(C1/2)
    C3 = (S2-50)+1
    S4 = int(C3/2)
    return IN, C1, S2, C3, S4


def read_data(filename, delimiter=','):
    with open(filename, 'r') as my_file:
        reader = csv.reader(my_file, delimiter=delimiter)
        my_list = list(reader)[0]
        my_list= [float(i) for i in my_list]
        return my_list

# %% [markdown]
# ## AGN Emission Lines (3000 - 8000 A)
# https://ned.ipac.caltech.edu/level5/Netzer/Netzer2_1.html
#
# ```
# CIII λ977
# OVI λ1035
# Lα
# NV λ1240
# OI λ1304
# CII λ1336
# SiIV,OIV] λ1400
# NIV] λ1486
# CIV λ1549
# HeII λ1640
# OIII] λ1663
# NIII] λ1750
# CIII] λ1909
# FeII λ(2200-2800)
# MgII λ2798
# [NeV] λ3426
# [OII] λ3727
# [NeIII] λ3869
# HeII λ4686
# Hβ λ4861
# [OIII] λ4959,5007
# FeII λ(4500-5400)
# HeI λ5876
# [FeVII] λ6087
# [OI] λ6300
# [FeX] λ6374
# Hα λ6563
# [NII] λ6583
# [SII] λ6716,6731
# CaII λ8498-8662
# [SIII] λ9069,9532
# ```
#
# The emission line spectrum of active galactic nuclei and the unifying scheme
# https://link.springer.com/article/10.1007%2Fs001590000006
#
# ```
# (Broad permmited lines)
# HI, HeI λλ5876,6678,7065
# He II λ4686
# Fe II visible domain
#
# (narrow line)
# [Fe VII] λ6087
# [Fe X] λ6375
# [Fe XI] λ7892
# ```
#
# add more balmer lines
# ```
# Hγ λ4340
# H-δ λ4102
# ```
#
#
# FeII Lines, Table I in
# https://arxiv.org/pdf/1004.2212.pdf
#
#
# without FeII:
#
# lines = [3869,4102,4340,4686,4861,4959,5007,5876,6087,6300,6374,6563,6583,6678,6716,6731,7065]
#
#
# with Fe II:
#
# lines = [3869,4102,4340,4473,4489,4491,4508,4515,4520,4523,4534,4542,4549,4556,4576,4583,4621,4629,4667,4686,4731,4861,4924,4959,4993,5007,5018,5146,5169,5198,5235,5265,5276,5284,5317,5326,5338,5363,5414,5425,5876,6087,6300,6374,6563,6583,6678,6716,6731,7065]

# %%
def _filters(lines, width, Ha_width=280, Hb_width=120, Hg_width=60):
    boundery_0 = np.array([[line-width/2,line+width/2] for line in lines if line<4338]).flatten()
    boundery_Hg = np.array([4340-Hg_width/2,4340+Hg_width/2]).flatten()
    boundery_1 = np.array([[line-width/2,line+width/2] for line in lines if (line>4342 and line<4860)]).flatten()
    boundery_Hb = np.array([4861-Hb_width/2,4861+Hb_width/2]).flatten()
    boundery_2 = np.array([[line-width/2,line+width/2] for line in lines if (line>4862 and line<6560)]).flatten()
    boundery_Ha = np.array([6563-Ha_width/2,6563+Ha_width/2]).flatten()
    boundery_3 = np.array([[line-width/2,line+width/2] for line in lines if line>6566]).flatten()
    boundery = np.concatenate((boundery_0, boundery_Hg, boundery_1,boundery_Hb,boundery_2,boundery_Ha,boundery_3),axis=0).reshape(-1,2)
    # 1st filter, filter the right boundery, ignore those right right bouderies smaller than the previous one
    index = [1]
    while len(index):
        signs = np.sign(boundery[1:]-boundery[:-1])
        index = np.argwhere(signs==-1)[:,0]+1
        if len(index)>0:
            boundery = np.delete(boundery,index,0)
    #print(boundery)
    # 2nd filter, compare right boundery and next left boundery, if smaller, merge two intervals.
    boundery = boundery.flatten()
    filters = []
    filters.append(boundery[0]) 
    i = 1
    while i< (len(boundery)-1):
        if boundery[i]<boundery[i+1]:
            filters.append(boundery[i])
            i=i+1
        else: 
            i=i+2
    filters.append(boundery[-1])
    return np.array(filters).reshape(-1,2)

def _filterTensor(tensor, lines, width, begin=3800, end=7500):
    filters = _filters(lines, width).flatten()
    filters = np.insert(filters,0,begin)
    filters = np.append(filters,end)
    filters = filters.reshape(-1,2)
    filters = (filters-3800).astype(int)
    if len(tensor.size()) == 1:
        return torch.cat([tensor[f[0]:f[1]] for f in filters],dim=1), filters
    else:
        return torch.cat([tensor[:,f[0]:f[1]] for f in filters],dim=1), filters

# %% [markdown]
# ## read  data

# %%
# The feature size is 1x(7500-3800+1), a pixel to one wavelenght
# merge data in previouly defined in different files
sy19_feature_train = read_data('sy19-pixels-3800-7500-redshifted-normalized.csv', delimiter=',')
sy19_feature_test = read_data('sy19-test-pixels-3800-7500-redshifted-normalized.csv', delimiter=',')
sy20_feature_1 = read_data('sy20-pixels-3800-7500-redshifted-normalized.csv', delimiter=',')
sy20_feature_2 = read_data('sy20-test-pixels-3800-7500-redshifted-normalized.0.csv', delimiter=',')
sy20_feature_3 = read_data('sy20-test-pixels-3800-7500-redshifted-normalized.1.csv', delimiter=',')
sy20_feature_4 = read_data('sy20-test-pixels-3800-7500-redshifted-normalized.2.csv', delimiter=',')
sy20_feature_5 = read_data('sy20-test-pixels-3800-7500-redshifted-normalized.3.csv', delimiter=',')
sy20_feature_6 = read_data('sy20-test-pixels-3800-7500-redshifted-normalized.4.csv', delimiter=',')
sy20_feature_7 = read_data('sy20-test-pixels-3800-7500-redshifted-normalized.5.csv', delimiter=',')
sy20_feature_8 = read_data('sy20-test-pixels-3800-7500-redshifted-normalized.6.csv', delimiter=',')

# %%
# read sy19 with noise   
sy19_noise_feature_train = []
for file in glob.glob('sy19-pixels*noise*'):
    print('reading:', file)
    file_feature = read_data(file, delimiter=',')
    sy19_noise_feature_train = np.concatenate((sy19_noise_feature_train, file_feature), axis=0)

sy19_noise_feature_test = []
for file in glob.glob('sy19-test*noise*'):
    print('reading:', file)
    file_feature = read_data(file, delimiter=',')
    sy19_noise_feature_test = np.concatenate((sy19_noise_feature_test, file_feature), axis=0)
# Out:
# reading: sy19-pixels-3800-7500-redshifted-normalized-noise.0.csv
# reading: sy19-pixels-3800-7500-redshifted-normalized-noise.1.csv
# reading: sy19-pixels-3800-7500-redshifted-normalized-noise.2.csv
# reading: sy19-pixels-3800-7500-redshifted-normalized-noise.3.csv
# reading: sy19-pixels-3800-7500-redshifted-normalized-noise.4.csv
# reading: sy19-pixels-3800-7500-redshifted-normalized-noise.5.csv
# reading: sy19-pixels-3800-7500-redshifted-normalized-noise.6.csv
# reading: sy19-pixels-3800-7500-redshifted-normalized-noise.7.csv
# reading: sy19-pixels-3800-7500-redshifted-normalized-noise.8.csv
# reading: sy19-pixels-3800-7500-redshifted-normalized-noise.9.csv
# reading: sy19-test-pixels-3800-7500-redshifted-normalized-noise.0.csv
# reading: sy19-test-pixels-3800-7500-redshifted-normalized-noise.1.csv
# reading: sy19-test-pixels-3800-7500-redshifted-normalized-noise.2.csv
# reading: sy19-test-pixels-3800-7500-redshifted-normalized-noise.3.csv
# reading: sy19-test-pixels-3800-7500-redshifted-normalized-noise.4.csv
# reading: sy19-test-pixels-3800-7500-redshifted-normalized-noise.5.csv
# reading: sy19-test-pixels-3800-7500-redshifted-normalized-noise.6.csv
# reading: sy19-test-pixels-3800-7500-redshifted-normalized-noise.7.csv
# reading: sy19-test-pixels-3800-7500-redshifted-normalized-noise.8.csv
# reading: sy19-test-pixels-3800-7500-redshifted-normalized-noise.9.csv

# %%
##  Small sample pre-traning
#sy19_feature = sy19_feature_1
#sy20_feature = sy20_feature_1

## Full sample
sy19_feature_train = np.concatenate((sy19_feature_train,  sy19_noise_feature_train), axis=0)
sy20_feature = np.concatenate((sy20_feature_1, sy20_feature_2,sy20_feature_3,sy20_feature_4,\
                               sy20_feature_5,sy20_feature_6,sy20_feature_7,sy20_feature_8), axis=0)

sy19_feature_train = torch.Tensor(sy19_feature_train).view(-1,7500-3800+1)
sy19_feature_test = torch.Tensor(sy19_feature_test).view(-1,7500-3800+1)
sy20_feature = torch.Tensor(sy20_feature).view(-1,7500-3800+1)

# %%
# filter wavelength
lines = [3869,4102,4340,4473,4489,4491,4508,4515,4520,4523,4534,4542,4549,4556,4576,4583,4621,4629,4667,4686,4731,4861,4924,4959,4993,5007,5018,5146,5169,5198,5235,5265,5276,5284,5317,5326,5338,5363,5414,5425,5876,6087,6300,6374,6563,6583,6678,6716,6731,7065]
width = 50

sy19_feature_train_filtered, filters = _filterTensor(sy19_feature_train, lines, width, begin=3800, end=7500)
sy19_feature_test_filtered, filters = _filterTensor(sy19_feature_test, lines, width, begin=3800, end=7500)
sy20_feature_filtered, filters = _filterTensor(sy20_feature, lines, width, begin=3800, end=7500)

# %%
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(12,6), sharex=True, sharey=True)
plt.subplots_adjust(wspace = 0.05)
for i in range(10):
    plt.sca(axs[0])
    axs[0].set_yticklabels([])
    plotData(sy19_feature_test[i]+i/5)
plotFilters(filters)
plt.legend(title='Seyfert 1s',loc=2)
for i in range(10):
    plt.sca(axs[1])
    axs[1].set_yticklabels([])
    plotData(sy20_feature[i]+i/5)
plotFilters(filters)
plt.legend(title='Seyfert 2',loc=2)


plt.xlim(3800,7500)

plt.ylabel('Density')
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# (3800, 7500)

# %%
# classify 1.9 as 1, and 2 as 0. 
sy19_label_train = torch.ones(sy19_feature_train.size(0),dtype=torch.long)
sy19_label_test = torch.ones(sy19_feature_test.size(0),dtype=torch.long)
sy20_label = torch.zeros(sy20_feature.size(0),dtype=torch.long)

# create indices
sy19_indice_train = torch.linspace(0,len(sy19_feature_train)-1,len(sy19_feature_train)).int()
sy19_indice_test = torch.linspace(0,len(sy19_feature_test)-1,len(sy19_feature_test)).int()
sy20_indice = torch.linspace(0,len(sy20_feature)-1,len(sy20_feature)).int()

# taking same number of 1.9 and 2.0 seyfert galaxies
sy19_dataset_train = TensorDataset(sy19_indice_train,sy19_feature_train_filtered,sy19_label_train)
sy19_dataset_test = TensorDataset(sy19_indice_test,sy19_feature_test_filtered,sy19_label_test)

sy20_dataset_train = TensorDataset(sy20_indice[:len(sy19_dataset_train)],sy20_feature_filtered[:len(sy19_dataset_train)],sy20_label[:len(sy19_dataset_train)])
sy20_dataset_test = TensorDataset(sy20_indice[len(sy19_dataset_train):],sy20_feature_filtered[len(sy19_dataset_train):],sy20_label[len(sy19_dataset_train):])

# merge the test dataset
dataset = ConcatDataset((sy19_dataset_train,sy20_dataset_train))

# %% [markdown]
# ## CNN Network - One layer of Full CNN

# %% [markdown]
# ### computing output size of image
#
#
# - i = input
# - o = output
# - p = padding
# - k = kernel_size
# - s = stride
# - d = dilation
#
# o = [i + 2*p - k - (k-1)*(d-1)]/s + 1
#
# In your case this gives o = [32 + 2 - 3 - 2*1]/1 +1 = [29] + 1 = 30.
# Now, you could set all your parameters and “solve” the equation for p.
# You will see, that p=2 will give you an output size of 32.
#
# You could  with some tools like ezyang’s convolution visualizer 308 or calculate it with this formula:
# https://ezyang.github.io/convolution-visualizer/index.html

# %% [markdown]
# ###  Network Map
#
# | Layer | Type | Maps | Kernel_size | Padding | Stride | Image_size | Activation | Comment |
# | --- | --- | --- | --- | --- | --- | --- | --- | --- |
# |  Out | Linear | - | - | - | - | 2 | - |  |
# |  F7 | Linear | - | - | - | - | 100 | ReLU | 1000 -> 100  |
# |  D6 | Dropout (0.5) | - | - | - | - | - | - | - |
# |  C5 | Convolution | 1000 | 888 | 0 | 1 | 1 | ReLU |  |
# |  S4 | Avg Pooling | 128 | 2 | 0 | 2 | 888 | - |  |
# |  C3 | Convolution | 128 | 50 | 0 | 1 | 1777 | ReLU |  |
# |  S2 | Avg Pooling | 64 | 2 | 0 | 2 | 1826 | - |  |
# |  C1 | Convolution | 64 | 50 | 0 | 1 | 3652 | ReLU |  |
# | In | Input | 1 | - | - |- | 3701 |- | |

# %%
sizes = sizeMap(sy19_feature_test_filtered[1].size(0))

# %%
sizes
# Out:
# (2079, 2030, 1015, 966, 483)

# %%
class simpleCNN(nn.Module):
    
    def __init__(self):
        super(simpleCNN, self).__init__()
        self.C1 = nn.Conv1d(1, 64, 50)
        self.S2 = nn.AvgPool1d(2, stride=2)
        self.C3 = nn.Conv1d(64, 128, 50)
        self.S4 = nn.AvgPool1d(2, stride=2)
        self.C5 = nn.Conv1d(128, 1000, sizes[4])
        self.D6 = nn.Dropout(0.5)
        self.F7 = nn.Linear(1000, 100)
        self.Out= nn.Linear(100, 2)
        
    def forward(self, x):
        x = F.relu(self.C1(x),inplace=True)
        x = self.S2(x)
        x = F.relu(self.C3(x),inplace=True)
        x = self.S4(x)
        x = F.relu(self.C5(x),inplace=True)
        x = self.D6(x)
        x = x.view(x.size(0),-1)
        x = F.relu(self.F7(x),inplace=True)
        x = self.Out(x)
        return x

# %%
net = simpleCNN()
print(net)
# Out:
# simpleCNN(
#   (C1): Conv1d(1, 64, kernel_size=(50,), stride=(1,))
#   (S2): AvgPool1d(kernel_size=(2,), stride=(2,), padding=(0,))
#   (C3): Conv1d(64, 128, kernel_size=(50,), stride=(1,))
#   (S4): AvgPool1d(kernel_size=(2,), stride=(2,), padding=(0,))
#   (C5): Conv1d(128, 1000, kernel_size=(483,), stride=(1,))
#   (D6): Dropout(p=0.5, inplace=False)
#   (F7): Linear(in_features=1000, out_features=100, bias=True)
#   (Out): Linear(in_features=100, out_features=2, bias=True)
# )

# %%
## Test
x = torch.randn(5,1,sizes[0])
net(x)
# Out:
# tensor([[0.0532, 0.0804],
#         [0.0492, 0.0658],
#         [0.0638, 0.1075],
#         [0.0565, 0.0892],
#         [0.0604, 0.0860]], grad_fn=<AddmmBackward>)

# %% [markdown]
# ### Check GPU availabel

# %%
use_gpu = torch.cuda.is_available()
if use_gpu:
    net.cuda(3)
    device = torch.device('cuda:3')
    print ('USE GPU')
else:
    device = torch.device('cpu')
    print ('USE CPU')
# Out:
# USE GPU

# %% [markdown]
# ### define  accuracy

# %%
def accuracy(y_hat, y):
#    y_hat = torch.sign(y_hat)
    return (y_hat.argmax(dim=1) == y).float().mean().item()

def evaluate_accuracy(data_iter, net, device):
    acc = torch.tensor([0.0], device=device)
    for (index, img, label) in data_iter:
        img = img.view(-1,1,sizes[0])
        # 如果 device 是 GPU，将数据复制到 GPU 上。
        if use_gpu:
            index, img, label = index.to(device), img.to(device), label.to(device)
        acc += accuracy(net(img), label)
    return acc.item() / len(data_iter)

# %% [markdown]
# ### TRAINING

# %%
learning_rate = 0.01

loss = nn.CrossEntropyLoss() # 包含了softmax 和 cross entropy
optimizer = optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9)
#optimizer = optim.Adam(net.parameters(), lr=learning_rate, betas=(0.9,0.999), eps=1e-8)
#optimizer = optim.SGD(net.parameters(), lr=learning_rate)

# %%
num_epochs = 500

batch_size = 64
train_iter = DataLoader(dataset, batch_size=batch_size, shuffle=True, num_workers=4)

# %%
## laod previous traning results
#
#net.load_state_dict(torch.load('cuda3-GOOD.pt'))
#
#previous = pd.read_csv('./runs/acc-list-cuda3-2019-07-22-15-02-10-826651-GOOD.csv', header=0, comment='#')
#
#loss_list = list(previous['loss'])
#sy19_test_acc_list = list(previous['sy19_test_acc'])
#sy20_test_acc_list = list(previous['sy20_test_acc'])
#train_acc_list = list(previous['train_acc'])

# %%
sy19_test_acc_list = []
sy20_test_acc_list = []
train_acc_list = []
loss_list = []

# %%
for epoch in range(num_epochs):
    net.train() 
    start = time.time()
    train_l_sum = 0.
    train_acc_sum = 0.
    for (index, img, label) in train_iter:
        img = img.view(-1,1,sizes[0])
        if use_gpu:
            index, img, label = index.to(device), img.to(device), label.to(device)
        optimizer.zero_grad()
        predict = net(img)
        l = loss(predict, label.view(-1))
        l.backward()
        optimizer.step()
        train_l_sum += l.data.item()
        train_acc_sum += accuracy(predict, label.view(-1))
        #print(l)
    
    if ((epoch+1)%1 ==0):
        net.eval() 
        sy19_test_iter = DataLoader(sy19_dataset_test, batch_size=batch_size, shuffle=True, num_workers=4)
        sy19_test_acc = evaluate_accuracy(sy19_test_iter, net, device)
        sy20_test_iter = DataLoader(sy20_dataset_test, batch_size=batch_size, shuffle=True, num_workers=4)
        sy20_test_acc = evaluate_accuracy(sy20_test_iter, net, device)
        
        print('epoch %d, loss %.6f, train acc %.6f, sy19 test acc  %.4f, sy20 test acc  %.4f, '
                'time %.1f sec' % (epoch + 1, train_l_sum / len(train_iter),
                                    train_acc_sum / len(train_iter),
                                    sy19_test_acc, sy20_test_acc, time.time() - start))
        sy19_test_acc_list.append(sy19_test_acc)
        sy20_test_acc_list.append(sy20_test_acc)
        loss_list.append(train_l_sum / len(train_iter))
        train_acc_list.append(train_acc_sum / len(train_iter))
        if (train_l_sum / len(train_iter) < 0.1):
            learning_rate = 0.001
            optimizer = optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9)
        if (train_l_sum / len(train_iter) < 0.005):
            learning_rate = 0.0001
            optimizer = optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9)
# Out:
# epoch 1, loss 0.659513, train acc 0.609675, sy19 test acc  0.8136, sy20 test acc  0.4013, time 24.5 sec
# epoch 2, loss 0.612455, train acc 0.648738, sy19 test acc  0.4627, sy20 test acc  0.6861, time 24.6 sec
# epoch 3, loss 0.603965, train acc 0.649339, sy19 test acc  0.8582, sy20 test acc  0.4035, time 24.6 sec
# epoch 4, loss 0.589095, train acc 0.676082, sy19 test acc  0.8589, sy20 test acc  0.3723, time 24.7 sec
# epoch 5, loss 0.588759, train acc 0.672776, sy19 test acc  0.7933, sy20 test acc  0.5049, time 24.7 sec
# epoch 6, loss 0.564216, train acc 0.684645, sy19 test acc  0.7142, sy20 test acc  0.5374, time 24.8 sec
# epoch 7, loss 0.566253, train acc 0.699970, sy19 test acc  0.7439, sy20 test acc  0.4891, time 24.8 sec
# epoch 8, loss 0.551427, train acc 0.720102, sy19 test acc  0.6969, sy20 test acc  0.6266, time 24.8 sec
# epoch 9, loss 0.517458, train acc 0.748798, sy19 test acc  0.5796, sy20 test acc  0.7078, time 24.9 sec
# epoch 10, loss 0.512527, train acc 0.745643, sy19 test acc  0.8695, sy20 test acc  0.5169, time 24.9 sec
# epoch 11, loss 0.463099, train acc 0.773287, sy19 test acc  0.7479, sy20 test acc  0.6687, time 24.9 sec
# epoch 12, loss 0.387654, train acc 0.819411, sy19 test acc  0.6023, sy20 test acc  0.9245, time 24.9 sec
# epoch 13, loss 0.311737, train acc 0.864784, sy19 test acc  0.7075, sy20 test acc  0.9454, time 24.9 sec
# epoch 14, loss 0.294456, train acc 0.873798, sy19 test acc  0.3507, sy20 test acc  0.9924, time 24.9 sec
# epoch 15, loss 0.280583, train acc 0.875901, sy19 test acc  0.7974, sy20 test acc  0.9039, time 24.8 sec
# epoch 16, loss 0.226926, train acc 0.910006, sy19 test acc  0.8332, sy20 test acc  0.8838, time 24.9 sec
# epoch 17, loss 0.216782, train acc 0.911508, sy19 test acc  0.6536, sy20 test acc  0.9591, time 24.9 sec
# epoch 18, loss 0.175910, train acc 0.931791, sy19 test acc  0.7208, sy20 test acc  0.9512, time 24.8 sec
# epoch 19, loss 0.163188, train acc 0.934645, sy19 test acc  0.7447, sy20 test acc  0.9341, time 24.8 sec
# epoch 20, loss 0.165339, train acc 0.935096, sy19 test acc  0.8221, sy20 test acc  0.8951, time 24.8 sec
# epoch 21, loss 0.145028, train acc 0.941857, sy19 test acc  0.6469, sy20 test acc  0.9653, time 24.9 sec
# epoch 22, loss 0.140915, train acc 0.943059, sy19 test acc  0.7914, sy20 test acc  0.9189, time 24.9 sec
# epoch 23, loss 0.127853, train acc 0.948017, sy19 test acc  0.6806, sy20 test acc  0.9649, time 24.8 sec
# epoch 24, loss 0.126677, train acc 0.946214, sy19 test acc  0.7127, sy20 test acc  0.9201, time 24.8 sec
# epoch 25, loss 0.125775, train acc 0.948918, sy19 test acc  0.7033, sy20 test acc  0.9461, time 24.8 sec
# epoch 26, loss 0.114116, train acc 0.955228, sy19 test acc  0.7508, sy20 test acc  0.9198, time 24.9 sec
# epoch 27, loss 0.104672, train acc 0.957031, sy19 test acc  0.7479, sy20 test acc  0.9363, time 24.8 sec
# epoch 28, loss 0.092052, train acc 0.962590, sy19 test acc  0.8021, sy20 test acc  0.9091, time 24.9 sec
# epoch 29, loss 0.075278, train acc 0.972206, sy19 test acc  0.7260, sy20 test acc  0.9454, time 24.8 sec
# epoch 30, loss 0.068281, train acc 0.975361, sy19 test acc  0.7352, sy20 test acc  0.9380, time 24.8 sec
# epoch 31, loss 0.066634, train acc 0.974008, sy19 test acc  0.7411, sy20 test acc  0.9369, time 24.8 sec
# epoch 32, loss 0.063348, train acc 0.977764, sy19 test acc  0.7398, sy20 test acc  0.9405, time 24.8 sec
# epoch 33, loss 0.060010, train acc 0.978215, sy19 test acc  0.7395, sy20 test acc  0.9368, time 24.8 sec
# epoch 34, loss 0.057284, train acc 0.978365, sy19 test acc  0.7072, sy20 test acc  0.9526, time 24.8 sec
# epoch 35, loss 0.057328, train acc 0.979718, sy19 test acc  0.7393, sy20 test acc  0.9415, time 24.8 sec
# epoch 36, loss 0.056843, train acc 0.980319, sy19 test acc  0.7369, sy20 test acc  0.9419, time 24.8 sec
# epoch 37, loss 0.057353, train acc 0.979567, sy19 test acc  0.7286, sy20 test acc  0.9485, time 24.8 sec
# epoch 38, loss 0.053304, train acc 0.982121, sy19 test acc  0.7458, sy20 test acc  0.9385, time 24.8 sec
# epoch 39, loss 0.052197, train acc 0.981220, sy19 test acc  0.7303, sy20 test acc  0.9444, time 24.8 sec
# epoch 40, loss 0.049687, train acc 0.984675, sy19 test acc  0.7277, sy20 test acc  0.9464, time 24.9 sec
# epoch 41, loss 0.049932, train acc 0.983023, sy19 test acc  0.7602, sy20 test acc  0.9327, time 24.9 sec
# epoch 42, loss 0.050478, train acc 0.981370, sy19 test acc  0.7208, sy20 test acc  0.9478, time 24.8 sec
# epoch 43, loss 0.047337, train acc 0.985427, sy19 test acc  0.7419, sy20 test acc  0.9377, time 24.8 sec
# epoch 44, loss 0.047045, train acc 0.984826, sy19 test acc  0.7480, sy20 test acc  0.9387, time 24.8 sec
# epoch 45, loss 0.046136, train acc 0.985727, sy19 test acc  0.7352, sy20 test acc  0.9429, time 24.8 sec
# epoch 46, loss 0.043036, train acc 0.987230, sy19 test acc  0.7191, sy20 test acc  0.9518, time 24.8 sec
# epoch 47, loss 0.044776, train acc 0.986178, sy19 test acc  0.7332, sy20 test acc  0.9456, time 24.8 sec
# epoch 48, loss 0.043246, train acc 0.986028, sy19 test acc  0.7506, sy20 test acc  0.9411, time 24.8 sec
# epoch 49, loss 0.044330, train acc 0.984976, sy19 test acc  0.7308, sy20 test acc  0.9490, time 24.8 sec
# epoch 50, loss 0.040826, train acc 0.986629, sy19 test acc  0.7442, sy20 test acc  0.9402, time 24.8 sec
# epoch 51, loss 0.040811, train acc 0.986629, sy19 test acc  0.7237, sy20 test acc  0.9482, time 24.8 sec
# epoch 52, loss 0.039910, train acc 0.987079, sy19 test acc  0.7328, sy20 test acc  0.9441, time 24.8 sec
# epoch 53, loss 0.038739, train acc 0.987079, sy19 test acc  0.7457, sy20 test acc  0.9377, time 24.8 sec
# epoch 54, loss 0.038651, train acc 0.987981, sy19 test acc  0.7524, sy20 test acc  0.9388, time 24.8 sec
# epoch 55, loss 0.035641, train acc 0.989032, sy19 test acc  0.7594, sy20 test acc  0.9341, time 24.8 sec
# epoch 56, loss 0.035673, train acc 0.988431, sy19 test acc  0.7278, sy20 test acc  0.9475, time 24.8 sec
# epoch 57, loss 0.032572, train acc 0.989483, sy19 test acc  0.7575, sy20 test acc  0.9375, time 24.8 sec
# epoch 58, loss 0.033911, train acc 0.989483, sy19 test acc  0.7461, sy20 test acc  0.9393, time 24.8 sec
# epoch 59, loss 0.032668, train acc 0.989934, sy19 test acc  0.7566, sy20 test acc  0.9380, time 24.8 sec
# epoch 60, loss 0.031978, train acc 0.990685, sy19 test acc  0.7661, sy20 test acc  0.9325, time 24.8 sec
# epoch 61, loss 0.033761, train acc 0.989032, sy19 test acc  0.7353, sy20 test acc  0.9470, time 24.8 sec
# epoch 62, loss 0.034190, train acc 0.990385, sy19 test acc  0.7795, sy20 test acc  0.9293, time 24.8 sec
# epoch 63, loss 0.030432, train acc 0.990685, sy19 test acc  0.7817, sy20 test acc  0.9245, time 24.8 sec
# epoch 64, loss 0.031694, train acc 0.990986, sy19 test acc  0.7374, sy20 test acc  0.9452, time 24.8 sec
# epoch 65, loss 0.030328, train acc 0.989483, sy19 test acc  0.7772, sy20 test acc  0.9213, time 24.8 sec
# epoch 66, loss 0.029351, train acc 0.990685, sy19 test acc  0.7663, sy20 test acc  0.9322, time 24.8 sec
# epoch 67, loss 0.028386, train acc 0.991136, sy19 test acc  0.7283, sy20 test acc  0.9492, time 24.8 sec
# epoch 68, loss 0.026163, train acc 0.992338, sy19 test acc  0.7347, sy20 test acc  0.9467, time 24.8 sec
# epoch 69, loss 0.026587, train acc 0.992188, sy19 test acc  0.7577, sy20 test acc  0.9357, time 24.8 sec
# epoch 70, loss 0.025019, train acc 0.993389, sy19 test acc  0.7647, sy20 test acc  0.9345, time 24.8 sec
# epoch 71, loss 0.023825, train acc 0.993239, sy19 test acc  0.7662, sy20 test acc  0.9311, time 24.8 sec
# epoch 72, loss 0.024151, train acc 0.993990, sy19 test acc  0.7525, sy20 test acc  0.9395, time 24.8 sec
# epoch 73, loss 0.023419, train acc 0.993089, sy19 test acc  0.7596, sy20 test acc  0.9361, time 24.8 sec
# epoch 74, loss 0.023059, train acc 0.994291, sy19 test acc  0.7438, sy20 test acc  0.9431, time 24.8 sec
# epoch 75, loss 0.020727, train acc 0.995192, sy19 test acc  0.7711, sy20 test acc  0.9258, time 24.8 sec
# epoch 76, loss 0.023451, train acc 0.993840, sy19 test acc  0.7616, sy20 test acc  0.9322, time 24.8 sec
# epoch 77, loss 0.020474, train acc 0.994742, sy19 test acc  0.7510, sy20 test acc  0.9377, time 24.8 sec
# epoch 78, loss 0.020666, train acc 0.993990, sy19 test acc  0.7391, sy20 test acc  0.9460, time 24.8 sec
# epoch 79, loss 0.020867, train acc 0.993840, sy19 test acc  0.7844, sy20 test acc  0.9175, time 24.8 sec
# epoch 80, loss 0.019540, train acc 0.995192, sy19 test acc  0.7552, sy20 test acc  0.9366, time 24.8 sec
# epoch 81, loss 0.018849, train acc 0.994742, sy19 test acc  0.7635, sy20 test acc  0.9360, time 24.8 sec
# epoch 82, loss 0.019239, train acc 0.995042, sy19 test acc  0.7889, sy20 test acc  0.9117, time 24.8 sec
# epoch 83, loss 0.020429, train acc 0.995192, sy19 test acc  0.7433, sy20 test acc  0.9461, time 24.8 sec
# epoch 84, loss 0.018420, train acc 0.995643, sy19 test acc  0.7500, sy20 test acc  0.9391, time 24.8 sec
# epoch 85, loss 0.017285, train acc 0.995643, sy19 test acc  0.7712, sy20 test acc  0.9246, time 24.8 sec
# epoch 86, loss 0.016936, train acc 0.995643, sy19 test acc  0.7724, sy20 test acc  0.9254, time 24.8 sec
# epoch 87, loss 0.016298, train acc 0.996394, sy19 test acc  0.7468, sy20 test acc  0.9441, time 24.8 sec
# epoch 88, loss 0.016299, train acc 0.995493, sy19 test acc  0.7613, sy20 test acc  0.9299, time 24.8 sec
# epoch 89, loss 0.014231, train acc 0.996695, sy19 test acc  0.7522, sy20 test acc  0.9384, time 24.8 sec
# epoch 90, loss 0.016844, train acc 0.996094, sy19 test acc  0.7441, sy20 test acc  0.9442, time 24.8 sec
# epoch 91, loss 0.014993, train acc 0.996995, sy19 test acc  0.7571, sy20 test acc  0.9347, time 24.8 sec
# epoch 92, loss 0.014097, train acc 0.996544, sy19 test acc  0.7684, sy20 test acc  0.9302, time 24.8 sec
# epoch 93, loss 0.014993, train acc 0.996995, sy19 test acc  0.7573, sy20 test acc  0.9385, time 24.8 sec
# epoch 94, loss 0.013433, train acc 0.997596, sy19 test acc  0.7504, sy20 test acc  0.9439, time 24.8 sec
# epoch 95, loss 0.014129, train acc 0.997145, sy19 test acc  0.7462, sy20 test acc  0.9421, time 24.8 sec
# epoch 96, loss 0.012754, train acc 0.997746, sy19 test acc  0.7566, sy20 test acc  0.9379, time 24.8 sec
# epoch 97, loss 0.011959, train acc 0.997596, sy19 test acc  0.7601, sy20 test acc  0.9370, time 24.8 sec
# epoch 98, loss 0.013960, train acc 0.996845, sy19 test acc  0.7572, sy20 test acc  0.9381, time 24.8 sec
# epoch 99, loss 0.011944, train acc 0.997446, sy19 test acc  0.7530, sy20 test acc  0.9406, time 24.8 sec
# epoch 100, loss 0.012479, train acc 0.997296, sy19 test acc  0.7566, sy20 test acc  0.9388, time 24.8 sec
# epoch 101, loss 0.012420, train acc 0.997446, sy19 test acc  0.7575, sy20 test acc  0.9375, time 24.8 sec
# epoch 102, loss 0.011696, train acc 0.997596, sy19 test acc  0.7422, sy20 test acc  0.9488, time 24.8 sec
# epoch 103, loss 0.012813, train acc 0.996094, sy19 test acc  0.7619, sy20 test acc  0.9264, time 24.8 sec
# epoch 104, loss 0.011280, train acc 0.997596, sy19 test acc  0.7680, sy20 test acc  0.9282, time 24.8 sec
# epoch 105, loss 0.010503, train acc 0.998498, sy19 test acc  0.7528, sy20 test acc  0.9405, time 24.8 sec
# epoch 106, loss 0.011373, train acc 0.997596, sy19 test acc  0.7550, sy20 test acc  0.9395, time 24.8 sec
# epoch 107, loss 0.009907, train acc 0.998347, sy19 test acc  0.7623, sy20 test acc  0.9356, time 24.8 sec
# epoch 108, loss 0.010876, train acc 0.997446, sy19 test acc  0.7617, sy20 test acc  0.9327, time 24.8 sec
# epoch 109, loss 0.008758, train acc 0.998798, sy19 test acc  0.7683, sy20 test acc  0.9281, time 24.8 sec
# epoch 110, loss 0.008924, train acc 0.998347, sy19 test acc  0.7548, sy20 test acc  0.9401, time 24.8 sec
# epoch 111, loss 0.009490, train acc 0.997897, sy19 test acc  0.7686, sy20 test acc  0.9267, time 24.8 sec
# epoch 112, loss 0.009228, train acc 0.998197, sy19 test acc  0.7661, sy20 test acc  0.9278, time 24.8 sec
# epoch 113, loss 0.008942, train acc 0.998648, sy19 test acc  0.7545, sy20 test acc  0.9396, time 24.8 sec
# epoch 114, loss 0.008562, train acc 0.998798, sy19 test acc  0.7643, sy20 test acc  0.9329, time 24.8 sec
# epoch 115, loss 0.008491, train acc 0.998498, sy19 test acc  0.7364, sy20 test acc  0.9496, time 24.8 sec
# epoch 116, loss 0.008146, train acc 0.998347, sy19 test acc  0.7552, sy20 test acc  0.9412, time 24.8 sec
# epoch 117, loss 0.009097, train acc 0.997746, sy19 test acc  0.7510, sy20 test acc  0.9398, time 24.8 sec
# epoch 118, loss 0.008415, train acc 0.998798, sy19 test acc  0.7616, sy20 test acc  0.9337, time 24.8 sec
# epoch 119, loss 0.007634, train acc 0.998948, sy19 test acc  0.7552, sy20 test acc  0.9384, time 24.8 sec
# epoch 120, loss 0.006644, train acc 0.998798, sy19 test acc  0.7602, sy20 test acc  0.9363, time 24.8 sec
# epoch 121, loss 0.007126, train acc 0.999249, sy19 test acc  0.7592, sy20 test acc  0.9362, time 24.8 sec
# epoch 122, loss 0.007692, train acc 0.998347, sy19 test acc  0.7616, sy20 test acc  0.9351, time 24.8 sec
# epoch 123, loss 0.007543, train acc 0.999099, sy19 test acc  0.7556, sy20 test acc  0.9381, time 24.8 sec
# epoch 124, loss 0.007640, train acc 0.998347, sy19 test acc  0.7635, sy20 test acc  0.9298, time 24.8 sec
# epoch 125, loss 0.007371, train acc 0.998047, sy19 test acc  0.7571, sy20 test acc  0.9420, time 24.8 sec
# epoch 126, loss 0.006564, train acc 0.999099, sy19 test acc  0.7506, sy20 test acc  0.9422, time 24.8 sec
# epoch 127, loss 0.006812, train acc 0.998648, sy19 test acc  0.7567, sy20 test acc  0.9404, time 24.8 sec
# epoch 128, loss 0.006827, train acc 0.998948, sy19 test acc  0.7469, sy20 test acc  0.9441, time 24.8 sec
# epoch 129, loss 0.006052, train acc 0.999399, sy19 test acc  0.7640, sy20 test acc  0.9341, time 24.8 sec
# epoch 130, loss 0.005636, train acc 0.999099, sy19 test acc  0.7505, sy20 test acc  0.9412, time 24.8 sec
# epoch 131, loss 0.006668, train acc 0.998948, sy19 test acc  0.7571, sy20 test acc  0.9350, time 24.8 sec
# epoch 132, loss 0.005370, train acc 0.999249, sy19 test acc  0.7662, sy20 test acc  0.9305, time 24.8 sec
# epoch 133, loss 0.005711, train acc 0.999099, sy19 test acc  0.7572, sy20 test acc  0.9362, time 24.8 sec
# epoch 134, loss 0.005292, train acc 0.999249, sy19 test acc  0.7728, sy20 test acc  0.9225, time 24.8 sec
# epoch 135, loss 0.005262, train acc 0.998948, sy19 test acc  0.7642, sy20 test acc  0.9341, time 24.8 sec
# epoch 136, loss 0.005980, train acc 0.998798, sy19 test acc  0.7671, sy20 test acc  0.9306, time 24.8 sec
# epoch 137, loss 0.005359, train acc 0.999549, sy19 test acc  0.7596, sy20 test acc  0.9352, time 24.8 sec
# epoch 138, loss 0.004967, train acc 0.999099, sy19 test acc  0.7534, sy20 test acc  0.9391, time 24.8 sec
# epoch 139, loss 0.004336, train acc 0.999700, sy19 test acc  0.7556, sy20 test acc  0.9384, time 24.8 sec
# epoch 140, loss 0.004735, train acc 0.999549, sy19 test acc  0.7548, sy20 test acc  0.9379, time 24.8 sec
# epoch 141, loss 0.004805, train acc 0.999249, sy19 test acc  0.7556, sy20 test acc  0.9381, time 24.8 sec
# epoch 142, loss 0.004859, train acc 0.999249, sy19 test acc  0.7547, sy20 test acc  0.9380, time 24.8 sec
# epoch 143, loss 0.004275, train acc 0.999549, sy19 test acc  0.7614, sy20 test acc  0.9365, time 24.8 sec
# epoch 144, loss 0.004424, train acc 0.999399, sy19 test acc  0.7568, sy20 test acc  0.9386, time 24.8 sec
# epoch 145, loss 0.004719, train acc 0.999249, sy19 test acc  0.7624, sy20 test acc  0.9365, time 24.8 sec
# epoch 146, loss 0.004392, train acc 0.999099, sy19 test acc  0.7623, sy20 test acc  0.9378, time 24.8 sec
# epoch 147, loss 0.004355, train acc 0.999549, sy19 test acc  0.7615, sy20 test acc  0.9366, time 24.8 sec
# epoch 148, loss 0.003910, train acc 0.999549, sy19 test acc  0.7596, sy20 test acc  0.9378, time 24.8 sec
# epoch 149, loss 0.003910, train acc 0.999700, sy19 test acc  0.7619, sy20 test acc  0.9375, time 24.8 sec
# epoch 150, loss 0.004171, train acc 0.999549, sy19 test acc  0.7641, sy20 test acc  0.9366, time 24.8 sec
# epoch 151, loss 0.004383, train acc 0.999399, sy19 test acc  0.7640, sy20 test acc  0.9342, time 24.8 sec
# epoch 152, loss 0.004491, train acc 0.999549, sy19 test acc  0.7639, sy20 test acc  0.9359, time 24.8 sec
# epoch 153, loss 0.004970, train acc 0.998648, sy19 test acc  0.7643, sy20 test acc  0.9371, time 24.8 sec
# epoch 154, loss 0.003966, train acc 0.999700, sy19 test acc  0.7623, sy20 test acc  0.9377, time 24.8 sec
# epoch 155, loss 0.004221, train acc 0.999700, sy19 test acc  0.7639, sy20 test acc  0.9371, time 24.8 sec
# epoch 156, loss 0.004365, train acc 0.999249, sy19 test acc  0.7620, sy20 test acc  0.9363, time 24.8 sec
# epoch 157, loss 0.004204, train acc 0.999249, sy19 test acc  0.7615, sy20 test acc  0.9362, time 24.8 sec
# epoch 158, loss 0.004485, train acc 0.999249, sy19 test acc  0.7621, sy20 test acc  0.9366, time 24.8 sec
# epoch 159, loss 0.004676, train acc 0.999399, sy19 test acc  0.7620, sy20 test acc  0.9369, time 24.8 sec
# epoch 160, loss 0.004412, train acc 0.999099, sy19 test acc  0.7645, sy20 test acc  0.9349, time 24.8 sec
# epoch 161, loss 0.003769, train acc 0.999549, sy19 test acc  0.7552, sy20 test acc  0.9391, time 24.8 sec
# epoch 162, loss 0.004366, train acc 0.999399, sy19 test acc  0.7640, sy20 test acc  0.9350, time 24.8 sec
# epoch 163, loss 0.004570, train acc 0.999249, sy19 test acc  0.7559, sy20 test acc  0.9390, time 24.8 sec
# epoch 164, loss 0.004358, train acc 0.999549, sy19 test acc  0.7621, sy20 test acc  0.9368, time 24.8 sec
# epoch 165, loss 0.003832, train acc 0.999700, sy19 test acc  0.7548, sy20 test acc  0.9392, time 24.8 sec
# epoch 166, loss 0.004564, train acc 0.999249, sy19 test acc  0.7638, sy20 test acc  0.9346, time 24.8 sec
# epoch 167, loss 0.004022, train acc 0.999249, sy19 test acc  0.7595, sy20 test acc  0.9365, time 24.8 sec
# epoch 168, loss 0.004471, train acc 0.999549, sy19 test acc  0.7642, sy20 test acc  0.9351, time 24.8 sec
# epoch 169, loss 0.004345, train acc 0.999549, sy19 test acc  0.7550, sy20 test acc  0.9380, time 24.8 sec
# epoch 170, loss 0.004179, train acc 0.999549, sy19 test acc  0.7594, sy20 test acc  0.9370, time 24.8 sec
# epoch 171, loss 0.003650, train acc 0.999700, sy19 test acc  0.7574, sy20 test acc  0.9378, time 24.8 sec
# epoch 172, loss 0.003775, train acc 0.999700, sy19 test acc  0.7597, sy20 test acc  0.9372, time 24.8 sec
# epoch 173, loss 0.003882, train acc 0.999549, sy19 test acc  0.7619, sy20 test acc  0.9353, time 24.8 sec
# epoch 174, loss 0.003962, train acc 0.999700, sy19 test acc  0.7623, sy20 test acc  0.9349, time 24.8 sec
# epoch 175, loss 0.004165, train acc 0.999249, sy19 test acc  0.7612, sy20 test acc  0.9344, time 24.8 sec
# epoch 176, loss 0.004622, train acc 0.999249, sy19 test acc  0.7644, sy20 test acc  0.9351, time 24.8 sec
# epoch 177, loss 0.004193, train acc 0.999700, sy19 test acc  0.7554, sy20 test acc  0.9376, time 24.8 sec
# epoch 178, loss 0.004008, train acc 0.999549, sy19 test acc  0.7621, sy20 test acc  0.9356, time 24.8 sec
# epoch 179, loss 0.003927, train acc 0.999700, sy19 test acc  0.7566, sy20 test acc  0.9375, time 24.8 sec
# epoch 180, loss 0.004306, train acc 0.999249, sy19 test acc  0.7642, sy20 test acc  0.9348, time 24.8 sec
# epoch 181, loss 0.004192, train acc 0.999099, sy19 test acc  0.7544, sy20 test acc  0.9396, time 24.8 sec
# epoch 182, loss 0.003903, train acc 0.999399, sy19 test acc  0.7616, sy20 test acc  0.9358, time 24.8 sec
# epoch 183, loss 0.003896, train acc 0.999399, sy19 test acc  0.7555, sy20 test acc  0.9385, time 24.8 sec
# epoch 184, loss 0.003953, train acc 0.999549, sy19 test acc  0.7636, sy20 test acc  0.9353, time 24.9 sec
# epoch 185, loss 0.004242, train acc 0.999700, sy19 test acc  0.7595, sy20 test acc  0.9366, time 24.8 sec
# epoch 186, loss 0.004533, train acc 0.999249, sy19 test acc  0.7616, sy20 test acc  0.9355, time 24.8 sec
# epoch 187, loss 0.003602, train acc 1.000000, sy19 test acc  0.7622, sy20 test acc  0.9362, time 24.8 sec
# epoch 188, loss 0.003865, train acc 0.999249, sy19 test acc  0.7623, sy20 test acc  0.9355, time 24.8 sec
# epoch 189, loss 0.004214, train acc 0.999249, sy19 test acc  0.7593, sy20 test acc  0.9366, time 24.8 sec
# epoch 190, loss 0.003403, train acc 0.999850, sy19 test acc  0.7549, sy20 test acc  0.9386, time 24.8 sec
# epoch 191, loss 0.003865, train acc 0.999399, sy19 test acc  0.7649, sy20 test acc  0.9356, time 24.8 sec
# epoch 192, loss 0.004159, train acc 0.999399, sy19 test acc  0.7616, sy20 test acc  0.9356, time 24.8 sec
# epoch 193, loss 0.004085, train acc 0.999249, sy19 test acc  0.7641, sy20 test acc  0.9355, time 24.8 sec
# epoch 194, loss 0.003805, train acc 0.999549, sy19 test acc  0.7574, sy20 test acc  0.9360, time 24.8 sec
# epoch 195, loss 0.004333, train acc 0.999399, sy19 test acc  0.7567, sy20 test acc  0.9368, time 24.8 sec
# epoch 196, loss 0.003655, train acc 0.999549, sy19 test acc  0.7567, sy20 test acc  0.9362, time 24.8 sec
# epoch 197, loss 0.004073, train acc 0.999249, sy19 test acc  0.7555, sy20 test acc  0.9418, time 24.8 sec
# epoch 198, loss 0.004249, train acc 0.999249, sy19 test acc  0.7578, sy20 test acc  0.9384, time 24.8 sec
# epoch 199, loss 0.003936, train acc 0.999549, sy19 test acc  0.7591, sy20 test acc  0.9368, time 24.8 sec
# epoch 200, loss 0.003683, train acc 0.999700, sy19 test acc  0.7596, sy20 test acc  0.9369, time 24.8 sec
# epoch 201, loss 0.003980, train acc 0.999399, sy19 test acc  0.7596, sy20 test acc  0.9362, time 24.8 sec
# epoch 202, loss 0.004260, train acc 0.999700, sy19 test acc  0.7553, sy20 test acc  0.9386, time 24.8 sec
# epoch 203, loss 0.004361, train acc 0.999249, sy19 test acc  0.7572, sy20 test acc  0.9356, time 24.8 sec
# epoch 204, loss 0.003767, train acc 0.999549, sy19 test acc  0.7591, sy20 test acc  0.9362, time 24.8 sec
# epoch 205, loss 0.003686, train acc 0.999850, sy19 test acc  0.7593, sy20 test acc  0.9363, time 24.8 sec
# epoch 206, loss 0.003849, train acc 0.999700, sy19 test acc  0.7573, sy20 test acc  0.9368, time 24.8 sec
# epoch 207, loss 0.003776, train acc 0.999549, sy19 test acc  0.7578, sy20 test acc  0.9366, time 24.8 sec
# epoch 208, loss 0.004359, train acc 0.999099, sy19 test acc  0.7554, sy20 test acc  0.9392, time 24.8 sec
# epoch 209, loss 0.004451, train acc 0.999249, sy19 test acc  0.7608, sy20 test acc  0.9350, time 24.8 sec
# epoch 210, loss 0.003692, train acc 0.999700, sy19 test acc  0.7546, sy20 test acc  0.9376, time 24.8 sec
# epoch 211, loss 0.003753, train acc 0.999700, sy19 test acc  0.7589, sy20 test acc  0.9361, time 24.8 sec
# epoch 212, loss 0.003928, train acc 0.999549, sy19 test acc  0.7568, sy20 test acc  0.9372, time 24.8 sec
# epoch 213, loss 0.003849, train acc 0.999549, sy19 test acc  0.7600, sy20 test acc  0.9351, time 24.8 sec
# epoch 214, loss 0.003440, train acc 0.999549, sy19 test acc  0.7594, sy20 test acc  0.9340, time 24.8 sec
# epoch 215, loss 0.003905, train acc 0.999399, sy19 test acc  0.7600, sy20 test acc  0.9342, time 24.8 sec
# epoch 216, loss 0.004122, train acc 0.999549, sy19 test acc  0.7620, sy20 test acc  0.9332, time 24.8 sec
# epoch 217, loss 0.003284, train acc 0.999850, sy19 test acc  0.7638, sy20 test acc  0.9345, time 24.8 sec
# epoch 218, loss 0.003472, train acc 0.999700, sy19 test acc  0.7614, sy20 test acc  0.9355, time 24.8 sec
# epoch 219, loss 0.003527, train acc 0.999850, sy19 test acc  0.7571, sy20 test acc  0.9369, time 24.8 sec
# epoch 220, loss 0.003852, train acc 0.999399, sy19 test acc  0.7586, sy20 test acc  0.9356, time 24.8 sec
# epoch 221, loss 0.004222, train acc 0.999700, sy19 test acc  0.7600, sy20 test acc  0.9344, time 24.8 sec
# epoch 222, loss 0.004194, train acc 0.999549, sy19 test acc  0.7548, sy20 test acc  0.9382, time 24.8 sec
# epoch 223, loss 0.003748, train acc 0.999700, sy19 test acc  0.7547, sy20 test acc  0.9357, time 24.8 sec
# epoch 224, loss 0.003251, train acc 0.999850, sy19 test acc  0.7548, sy20 test acc  0.9371, time 24.8 sec
# epoch 225, loss 0.003556, train acc 0.999850, sy19 test acc  0.7553, sy20 test acc  0.9370, time 24.8 sec
# epoch 226, loss 0.003403, train acc 0.999850, sy19 test acc  0.7571, sy20 test acc  0.9373, time 24.8 sec
# epoch 227, loss 0.003143, train acc 0.999850, sy19 test acc  0.7553, sy20 test acc  0.9392, time 24.8 sec
# epoch 228, loss 0.004700, train acc 0.999549, sy19 test acc  0.7574, sy20 test acc  0.9361, time 24.8 sec
# epoch 229, loss 0.003389, train acc 0.999700, sy19 test acc  0.7566, sy20 test acc  0.9379, time 24.8 sec
# epoch 230, loss 0.004131, train acc 0.999700, sy19 test acc  0.7574, sy20 test acc  0.9353, time 24.8 sec
# epoch 231, loss 0.003627, train acc 0.999700, sy19 test acc  0.7573, sy20 test acc  0.9353, time 24.8 sec
# epoch 232, loss 0.003496, train acc 0.999850, sy19 test acc  0.7598, sy20 test acc  0.9342, time 24.8 sec
# epoch 233, loss 0.003761, train acc 0.999249, sy19 test acc  0.7574, sy20 test acc  0.9348, time 24.8 sec
# epoch 234, loss 0.003530, train acc 0.999850, sy19 test acc  0.7543, sy20 test acc  0.9376, time 24.8 sec
# epoch 235, loss 0.003378, train acc 1.000000, sy19 test acc  0.7564, sy20 test acc  0.9368, time 24.8 sec
# epoch 236, loss 0.003630, train acc 0.999700, sy19 test acc  0.7601, sy20 test acc  0.9341, time 24.8 sec
# epoch 237, loss 0.003561, train acc 0.999399, sy19 test acc  0.7595, sy20 test acc  0.9355, time 24.8 sec
# epoch 238, loss 0.003469, train acc 0.999549, sy19 test acc  0.7582, sy20 test acc  0.9354, time 24.8 sec
# epoch 239, loss 0.003298, train acc 0.999850, sy19 test acc  0.7576, sy20 test acc  0.9363, time 24.8 sec
# epoch 240, loss 0.003379, train acc 0.999549, sy19 test acc  0.7622, sy20 test acc  0.9350, time 24.8 sec
# epoch 241, loss 0.003429, train acc 0.999700, sy19 test acc  0.7627, sy20 test acc  0.9344, time 24.8 sec
# epoch 242, loss 0.003305, train acc 0.999700, sy19 test acc  0.7554, sy20 test acc  0.9372, time 24.8 sec
# epoch 243, loss 0.004058, train acc 0.999099, sy19 test acc  0.7577, sy20 test acc  0.9358, time 24.8 sec
# epoch 244, loss 0.003645, train acc 0.999700, sy19 test acc  0.7541, sy20 test acc  0.9370, time 24.8 sec
# epoch 245, loss 0.003749, train acc 0.999850, sy19 test acc  0.7575, sy20 test acc  0.9350, time 24.8 sec
# epoch 246, loss 0.003540, train acc 0.999700, sy19 test acc  0.7545, sy20 test acc  0.9368, time 24.8 sec
# epoch 247, loss 0.003599, train acc 0.999399, sy19 test acc  0.7549, sy20 test acc  0.9407, time 24.8 sec
# epoch 248, loss 0.003465, train acc 0.999399, sy19 test acc  0.7568, sy20 test acc  0.9362, time 24.8 sec
# epoch 249, loss 0.003369, train acc 0.999700, sy19 test acc  0.7555, sy20 test acc  0.9374, time 24.8 sec
# epoch 250, loss 0.003551, train acc 0.999549, sy19 test acc  0.7568, sy20 test acc  0.9355, time 24.8 sec
# epoch 251, loss 0.004013, train acc 0.999549, sy19 test acc  0.7549, sy20 test acc  0.9382, time 24.8 sec
# epoch 252, loss 0.003804, train acc 0.999700, sy19 test acc  0.7570, sy20 test acc  0.9364, time 24.8 sec
# epoch 253, loss 0.003473, train acc 0.999850, sy19 test acc  0.7597, sy20 test acc  0.9349, time 24.8 sec
# epoch 254, loss 0.003298, train acc 0.999700, sy19 test acc  0.7573, sy20 test acc  0.9363, time 24.8 sec
# epoch 255, loss 0.003004, train acc 0.999850, sy19 test acc  0.7563, sy20 test acc  0.9362, time 24.8 sec
# epoch 256, loss 0.003587, train acc 0.999700, sy19 test acc  0.7576, sy20 test acc  0.9368, time 24.8 sec
# epoch 257, loss 0.003902, train acc 0.998948, sy19 test acc  0.7563, sy20 test acc  0.9364, time 24.8 sec
# epoch 258, loss 0.003409, train acc 0.999700, sy19 test acc  0.7571, sy20 test acc  0.9353, time 24.8 sec
# epoch 259, loss 0.003723, train acc 0.999399, sy19 test acc  0.7596, sy20 test acc  0.9347, time 24.8 sec
# epoch 260, loss 0.003657, train acc 0.999700, sy19 test acc  0.7619, sy20 test acc  0.9343, time 24.8 sec
# epoch 261, loss 0.003713, train acc 0.999549, sy19 test acc  0.7550, sy20 test acc  0.9379, time 24.8 sec
# epoch 262, loss 0.003598, train acc 0.999700, sy19 test acc  0.7575, sy20 test acc  0.9351, time 24.8 sec
# epoch 263, loss 0.004069, train acc 0.999549, sy19 test acc  0.7549, sy20 test acc  0.9376, time 24.8 sec
# epoch 264, loss 0.003753, train acc 0.999399, sy19 test acc  0.7573, sy20 test acc  0.9356, time 24.8 sec
# epoch 265, loss 0.004173, train acc 0.999249, sy19 test acc  0.7552, sy20 test acc  0.9365, time 24.8 sec
# epoch 266, loss 0.004038, train acc 0.998948, sy19 test acc  0.7615, sy20 test acc  0.9341, time 24.8 sec
# epoch 267, loss 0.003996, train acc 0.999399, sy19 test acc  0.7616, sy20 test acc  0.9337, time 24.8 sec
# epoch 268, loss 0.003558, train acc 0.999549, sy19 test acc  0.7623, sy20 test acc  0.9348, time 24.8 sec
# epoch 269, loss 0.003530, train acc 0.999700, sy19 test acc  0.7548, sy20 test acc  0.9389, time 24.8 sec
# epoch 270, loss 0.003321, train acc 0.999850, sy19 test acc  0.7598, sy20 test acc  0.9351, time 24.8 sec
# epoch 271, loss 0.003412, train acc 1.000000, sy19 test acc  0.7552, sy20 test acc  0.9360, time 24.8 sec
# epoch 272, loss 0.003150, train acc 0.999850, sy19 test acc  0.7602, sy20 test acc  0.9353, time 24.8 sec
# epoch 273, loss 0.003585, train acc 0.999549, sy19 test acc  0.7613, sy20 test acc  0.9353, time 24.8 sec
# epoch 274, loss 0.003151, train acc 0.999850, sy19 test acc  0.7546, sy20 test acc  0.9359, time 24.8 sec
# epoch 275, loss 0.003422, train acc 0.999700, sy19 test acc  0.7574, sy20 test acc  0.9357, time 24.9 sec
# epoch 276, loss 0.003608, train acc 0.999700, sy19 test acc  0.7593, sy20 test acc  0.9348, time 24.8 sec
# epoch 277, loss 0.003517, train acc 0.999850, sy19 test acc  0.7616, sy20 test acc  0.9345, time 24.8 sec
# epoch 278, loss 0.003094, train acc 0.999850, sy19 test acc  0.7570, sy20 test acc  0.9366, time 24.9 sec
# epoch 279, loss 0.003026, train acc 0.999850, sy19 test acc  0.7578, sy20 test acc  0.9349, time 24.8 sec
# epoch 280, loss 0.003255, train acc 0.999700, sy19 test acc  0.7576, sy20 test acc  0.9352, time 24.8 sec
# epoch 281, loss 0.003172, train acc 1.000000, sy19 test acc  0.7577, sy20 test acc  0.9357, time 24.8 sec
# epoch 282, loss 0.003511, train acc 0.999399, sy19 test acc  0.7572, sy20 test acc  0.9358, time 24.8 sec
# epoch 283, loss 0.003152, train acc 0.999850, sy19 test acc  0.7574, sy20 test acc  0.9342, time 24.8 sec
# epoch 284, loss 0.003256, train acc 0.999850, sy19 test acc  0.7598, sy20 test acc  0.9342, time 24.8 sec
# epoch 285, loss 0.003085, train acc 0.999850, sy19 test acc  0.7574, sy20 test acc  0.9346, time 24.8 sec
# epoch 286, loss 0.003033, train acc 0.999850, sy19 test acc  0.7575, sy20 test acc  0.9365, time 24.8 sec
# epoch 287, loss 0.003990, train acc 0.999399, sy19 test acc  0.7573, sy20 test acc  0.9361, time 24.8 sec
# epoch 288, loss 0.003717, train acc 0.999549, sy19 test acc  0.7575, sy20 test acc  0.9356, time 24.8 sec
# epoch 289, loss 0.003912, train acc 0.999399, sy19 test acc  0.7577, sy20 test acc  0.9360, time 24.8 sec
# epoch 290, loss 0.003392, train acc 0.999700, sy19 test acc  0.7571, sy20 test acc  0.9371, time 24.8 sec
# epoch 291, loss 0.003092, train acc 0.999850, sy19 test acc  0.7601, sy20 test acc  0.9349, time 24.8 sec
# epoch 292, loss 0.003264, train acc 0.999700, sy19 test acc  0.7547, sy20 test acc  0.9392, time 24.8 sec
# epoch 293, loss 0.003215, train acc 0.999850, sy19 test acc  0.7577, sy20 test acc  0.9365, time 24.8 sec
# epoch 294, loss 0.003454, train acc 0.999549, sy19 test acc  0.7570, sy20 test acc  0.9362, time 24.8 sec
# epoch 295, loss 0.002798, train acc 0.999700, sy19 test acc  0.7574, sy20 test acc  0.9371, time 24.8 sec
# epoch 296, loss 0.003491, train acc 0.999399, sy19 test acc  0.7552, sy20 test acc  0.9397, time 24.8 sec
# epoch 297, loss 0.003344, train acc 0.999700, sy19 test acc  0.7574, sy20 test acc  0.9355, time 24.8 sec
# epoch 298, loss 0.003175, train acc 0.999850, sy19 test acc  0.7576, sy20 test acc  0.9356, time 24.7 sec
# epoch 299, loss 0.003512, train acc 0.999399, sy19 test acc  0.7598, sy20 test acc  0.9342, time 24.8 sec
# epoch 300, loss 0.003155, train acc 1.000000, sy19 test acc  0.7572, sy20 test acc  0.9362, time 24.8 sec
# epoch 301, loss 0.003200, train acc 0.999850, sy19 test acc  0.7546, sy20 test acc  0.9383, time 24.8 sec
# epoch 302, loss 0.003492, train acc 0.999850, sy19 test acc  0.7572, sy20 test acc  0.9366, time 24.8 sec
# epoch 303, loss 0.002959, train acc 0.999700, sy19 test acc  0.7575, sy20 test acc  0.9377, time 24.8 sec
# epoch 304, loss 0.003332, train acc 0.999700, sy19 test acc  0.7592, sy20 test acc  0.9363, time 24.8 sec
# epoch 305, loss 0.003074, train acc 0.999850, sy19 test acc  0.7594, sy20 test acc  0.9352, time 24.8 sec
# epoch 306, loss 0.003128, train acc 0.999700, sy19 test acc  0.7581, sy20 test acc  0.9375, time 24.8 sec
# epoch 307, loss 0.003011, train acc 1.000000, sy19 test acc  0.7572, sy20 test acc  0.9349, time 24.8 sec
# epoch 308, loss 0.003437, train acc 0.999399, sy19 test acc  0.7594, sy20 test acc  0.9351, time 24.8 sec
# epoch 309, loss 0.002997, train acc 0.999850, sy19 test acc  0.7573, sy20 test acc  0.9369, time 24.8 sec
# epoch 310, loss 0.003069, train acc 0.999850, sy19 test acc  0.7582, sy20 test acc  0.9384, time 24.8 sec
# epoch 311, loss 0.003202, train acc 0.999850, sy19 test acc  0.7575, sy20 test acc  0.9369, time 24.8 sec
# epoch 312, loss 0.003097, train acc 0.999850, sy19 test acc  0.7576, sy20 test acc  0.9388, time 24.8 sec
# epoch 313, loss 0.003064, train acc 0.999850, sy19 test acc  0.7577, sy20 test acc  0.9377, time 24.8 sec
# epoch 314, loss 0.002892, train acc 0.999850, sy19 test acc  0.7572, sy20 test acc  0.9365, time 24.8 sec
# epoch 319, loss 0.003078, train acc 1.000000, sy19 test acc  0.7554, sy20 test acc  0.9385, time 24.8 sec
# epoch 320, loss 0.003322, train acc 0.999700, sy19 test acc  0.7579, sy20 test acc  0.9350, time 24.8 sec
# epoch 321, loss 0.002929, train acc 0.999549, sy19 test acc  0.7555, sy20 test acc  0.9399, time 24.8 sec
# epoch 322, loss 0.003380, train acc 0.999700, sy19 test acc  0.7553, sy20 test acc  0.9401, time 24.8 sec
# epoch 323, loss 0.003062, train acc 0.999700, sy19 test acc  0.7573, sy20 test acc  0.9357, time 24.8 sec
# epoch 324, loss 0.003153, train acc 0.999850, sy19 test acc  0.7575, sy20 test acc  0.9366, time 24.8 sec
# epoch 325, loss 0.003037, train acc 0.999850, sy19 test acc  0.7579, sy20 test acc  0.9358, time 24.8 sec
# epoch 326, loss 0.002863, train acc 0.999700, sy19 test acc  0.7548, sy20 test acc  0.9370, time 24.8 sec
# epoch 327, loss 0.003216, train acc 0.999549, sy19 test acc  0.7553, sy20 test acc  0.9375, time 24.8 sec
# epoch 328, loss 0.002776, train acc 0.999850, sy19 test acc  0.7576, sy20 test acc  0.9351, time 24.8 sec
# epoch 329, loss 0.003023, train acc 0.999850, sy19 test acc  0.7571, sy20 test acc  0.9363, time 24.8 sec
# epoch 330, loss 0.002875, train acc 0.999700, sy19 test acc  0.7576, sy20 test acc  0.9354, time 24.8 sec
# epoch 331, loss 0.003316, train acc 0.999549, sy19 test acc  0.7564, sy20 test acc  0.9373, time 24.8 sec
# epoch 332, loss 0.003050, train acc 0.999700, sy19 test acc  0.7573, sy20 test acc  0.9374, time 24.8 sec
# epoch 333, loss 0.002912, train acc 0.999850, sy19 test acc  0.7567, sy20 test acc  0.9372, time 24.8 sec
# epoch 334, loss 0.002695, train acc 1.000000, sy19 test acc  0.7552, sy20 test acc  0.9374, time 24.8 sec
# epoch 335, loss 0.003695, train acc 0.999249, sy19 test acc  0.7572, sy20 test acc  0.9390, time 24.8 sec
# epoch 336, loss 0.003093, train acc 0.999549, sy19 test acc  0.7576, sy20 test acc  0.9387, time 24.8 sec
# epoch 337, loss 0.003258, train acc 0.999700, sy19 test acc  0.7574, sy20 test acc  0.9382, time 24.8 sec
# epoch 338, loss 0.002899, train acc 1.000000, sy19 test acc  0.7575, sy20 test acc  0.9370, time 24.7 sec
# epoch 339, loss 0.002826, train acc 1.000000, sy19 test acc  0.7567, sy20 test acc  0.9381, time 24.8 sec
# epoch 340, loss 0.003035, train acc 0.999700, sy19 test acc  0.7577, sy20 test acc  0.9381, time 24.8 sec
# epoch 341, loss 0.002774, train acc 1.000000, sy19 test acc  0.7572, sy20 test acc  0.9375, time 24.8 sec
# epoch 342, loss 0.003427, train acc 0.999249, sy19 test acc  0.7575, sy20 test acc  0.9340, time 24.8 sec
# epoch 343, loss 0.003256, train acc 0.999549, sy19 test acc  0.7552, sy20 test acc  0.9383, time 24.8 sec
# epoch 344, loss 0.003300, train acc 0.999549, sy19 test acc  0.7545, sy20 test acc  0.9398, time 24.8 sec
# epoch 345, loss 0.002996, train acc 0.999850, sy19 test acc  0.7549, sy20 test acc  0.9397, time 24.8 sec
# epoch 346, loss 0.003364, train acc 0.999399, sy19 test acc  0.7573, sy20 test acc  0.9362, time 24.8 sec
# epoch 347, loss 0.002809, train acc 0.999850, sy19 test acc  0.7574, sy20 test acc  0.9342, time 24.8 sec
# epoch 348, loss 0.002835, train acc 0.999850, sy19 test acc  0.7547, sy20 test acc  0.9375, time 24.8 sec
# epoch 349, loss 0.002861, train acc 0.999850, sy19 test acc  0.7559, sy20 test acc  0.9371, time 24.7 sec
# epoch 350, loss 0.003244, train acc 0.999399, sy19 test acc  0.7553, sy20 test acc  0.9382, time 24.8 sec
# epoch 351, loss 0.003226, train acc 0.999700, sy19 test acc  0.7576, sy20 test acc  0.9357, time 24.8 sec
# epoch 352, loss 0.002888, train acc 0.999700, sy19 test acc  0.7578, sy20 test acc  0.9359, time 24.8 sec
# epoch 353, loss 0.002786, train acc 1.000000, sy19 test acc  0.7573, sy20 test acc  0.9375, time 24.8 sec
# epoch 354, loss 0.002945, train acc 0.999549, sy19 test acc  0.7573, sy20 test acc  0.9350, time 24.8 sec
# epoch 355, loss 0.002724, train acc 0.999700, sy19 test acc  0.7574, sy20 test acc  0.9355, time 24.8 sec
# epoch 356, loss 0.002707, train acc 0.999850, sy19 test acc  0.7573, sy20 test acc  0.9355, time 24.8 sec
# epoch 357, loss 0.003171, train acc 0.999549, sy19 test acc  0.7553, sy20 test acc  0.9398, time 24.8 sec
# epoch 358, loss 0.002928, train acc 0.999850, sy19 test acc  0.7568, sy20 test acc  0.9368, time 24.8 sec
# epoch 359, loss 0.003246, train acc 0.999399, sy19 test acc  0.7574, sy20 test acc  0.9372, time 24.8 sec
# epoch 360, loss 0.002698, train acc 0.999850, sy19 test acc  0.7574, sy20 test acc  0.9368, time 24.8 sec
# epoch 361, loss 0.002732, train acc 0.999850, sy19 test acc  0.7571, sy20 test acc  0.9358, time 24.8 sec
# epoch 362, loss 0.002565, train acc 1.000000, sy19 test acc  0.7575, sy20 test acc  0.9366, time 24.8 sec
# epoch 363, loss 0.002510, train acc 0.999850, sy19 test acc  0.7575, sy20 test acc  0.9366, time 24.8 sec
# epoch 364, loss 0.002866, train acc 0.999700, sy19 test acc  0.7572, sy20 test acc  0.9372, time 24.8 sec
# epoch 365, loss 0.003107, train acc 0.999399, sy19 test acc  0.7575, sy20 test acc  0.9369, time 24.8 sec
# epoch 366, loss 0.002969, train acc 0.999850, sy19 test acc  0.7554, sy20 test acc  0.9391, time 24.8 sec
# epoch 367, loss 0.002682, train acc 1.000000, sy19 test acc  0.7572, sy20 test acc  0.9383, time 24.8 sec
# epoch 368, loss 0.003324, train acc 0.999700, sy19 test acc  0.7573, sy20 test acc  0.9392, time 24.8 sec
# epoch 369, loss 0.002856, train acc 0.999850, sy19 test acc  0.7564, sy20 test acc  0.9365, time 24.8 sec
# epoch 370, loss 0.002939, train acc 0.999850, sy19 test acc  0.7575, sy20 test acc  0.9387, time 24.8 sec
# epoch 371, loss 0.003153, train acc 0.999549, sy19 test acc  0.7574, sy20 test acc  0.9363, time 24.8 sec
# epoch 372, loss 0.002875, train acc 0.999850, sy19 test acc  0.7577, sy20 test acc  0.9383, time 24.8 sec
# epoch 373, loss 0.002931, train acc 0.999850, sy19 test acc  0.7572, sy20 test acc  0.9370, time 24.8 sec
# epoch 374, loss 0.002932, train acc 0.999700, sy19 test acc  0.7571, sy20 test acc  0.9373, time 24.8 sec
# epoch 375, loss 0.003011, train acc 0.999850, sy19 test acc  0.7573, sy20 test acc  0.9355, time 24.8 sec
# epoch 376, loss 0.002828, train acc 1.000000, sy19 test acc  0.7568, sy20 test acc  0.9364, time 24.8 sec
# epoch 377, loss 0.002889, train acc 0.999549, sy19 test acc  0.7550, sy20 test acc  0.9385, time 24.8 sec
# epoch 378, loss 0.002827, train acc 0.999700, sy19 test acc  0.7576, sy20 test acc  0.9358, time 24.8 sec
# epoch 379, loss 0.002779, train acc 0.999850, sy19 test acc  0.7571, sy20 test acc  0.9360, time 24.8 sec
# epoch 380, loss 0.003139, train acc 0.999549, sy19 test acc  0.7576, sy20 test acc  0.9359, time 24.8 sec
# epoch 381, loss 0.002574, train acc 0.999850, sy19 test acc  0.7573, sy20 test acc  0.9362, time 24.8 sec
# epoch 382, loss 0.002793, train acc 0.999700, sy19 test acc  0.7574, sy20 test acc  0.9361, time 24.8 sec
# epoch 383, loss 0.002446, train acc 1.000000, sy19 test acc  0.7567, sy20 test acc  0.9364, time 24.8 sec
# epoch 384, loss 0.002804, train acc 0.999850, sy19 test acc  0.7576, sy20 test acc  0.9365, time 24.8 sec
# epoch 385, loss 0.002733, train acc 1.000000, sy19 test acc  0.7546, sy20 test acc  0.9382, time 24.8 sec
# epoch 386, loss 0.002447, train acc 1.000000, sy19 test acc  0.7567, sy20 test acc  0.9370, time 24.8 sec
# epoch 387, loss 0.002796, train acc 0.999700, sy19 test acc  0.7568, sy20 test acc  0.9365, time 24.8 sec
# epoch 388, loss 0.003143, train acc 0.999399, sy19 test acc  0.7592, sy20 test acc  0.9343, time 24.8 sec
# epoch 389, loss 0.002543, train acc 1.000000, sy19 test acc  0.7577, sy20 test acc  0.9358, time 24.8 sec
# epoch 390, loss 0.002751, train acc 0.999700, sy19 test acc  0.7596, sy20 test acc  0.9349, time 24.8 sec
# epoch 391, loss 0.002649, train acc 0.999850, sy19 test acc  0.7594, sy20 test acc  0.9346, time 24.8 sec
# epoch 392, loss 0.002825, train acc 0.999850, sy19 test acc  0.7573, sy20 test acc  0.9363, time 24.8 sec
# epoch 393, loss 0.002436, train acc 1.000000, sy19 test acc  0.7568, sy20 test acc  0.9365, time 24.8 sec
# epoch 394, loss 0.003411, train acc 0.999399, sy19 test acc  0.7576, sy20 test acc  0.9366, time 24.8 sec
# epoch 395, loss 0.002580, train acc 0.999850, sy19 test acc  0.7582, sy20 test acc  0.9365, time 24.8 sec
# epoch 396, loss 0.002753, train acc 0.999549, sy19 test acc  0.7571, sy20 test acc  0.9375, time 24.8 sec
# epoch 397, loss 0.003205, train acc 0.999700, sy19 test acc  0.7638, sy20 test acc  0.9309, time 24.8 sec
# epoch 398, loss 0.003171, train acc 0.999549, sy19 test acc  0.7568, sy20 test acc  0.9361, time 24.8 sec
# epoch 399, loss 0.002683, train acc 0.999700, sy19 test acc  0.7574, sy20 test acc  0.9387, time 24.8 sec
# epoch 400, loss 0.002398, train acc 1.000000, sy19 test acc  0.7577, sy20 test acc  0.9369, time 24.8 sec
# epoch 401, loss 0.002521, train acc 1.000000, sy19 test acc  0.7575, sy20 test acc  0.9384, time 24.8 sec
# epoch 402, loss 0.002933, train acc 0.999850, sy19 test acc  0.7568, sy20 test acc  0.9361, time 24.8 sec
# epoch 403, loss 0.002703, train acc 0.999700, sy19 test acc  0.7573, sy20 test acc  0.9384, time 24.8 sec
# epoch 404, loss 0.003107, train acc 0.999399, sy19 test acc  0.7572, sy20 test acc  0.9368, time 24.8 sec
# epoch 405, loss 0.002425, train acc 1.000000, sy19 test acc  0.7575, sy20 test acc  0.9373, time 24.8 sec
# epoch 406, loss 0.002853, train acc 0.999549, sy19 test acc  0.7571, sy20 test acc  0.9348, time 24.8 sec
# epoch 407, loss 0.003125, train acc 0.999399, sy19 test acc  0.7571, sy20 test acc  0.9373, time 24.8 sec
# epoch 408, loss 0.002689, train acc 0.999850, sy19 test acc  0.7570, sy20 test acc  0.9354, time 24.8 sec
# epoch 409, loss 0.002441, train acc 0.999850, sy19 test acc  0.7576, sy20 test acc  0.9368, time 24.8 sec
# epoch 410, loss 0.002496, train acc 1.000000, sy19 test acc  0.7575, sy20 test acc  0.9371, time 24.8 sec
# epoch 411, loss 0.002737, train acc 0.999700, sy19 test acc  0.7574, sy20 test acc  0.9368, time 24.8 sec
# epoch 412, loss 0.002510, train acc 1.000000, sy19 test acc  0.7575, sy20 test acc  0.9373, time 24.8 sec
# epoch 413, loss 0.003079, train acc 0.999700, sy19 test acc  0.7577, sy20 test acc  0.9367, time 24.8 sec
# epoch 414, loss 0.002642, train acc 0.999700, sy19 test acc  0.7576, sy20 test acc  0.9362, time 24.8 sec
# epoch 415, loss 0.002427, train acc 0.999850, sy19 test acc  0.7573, sy20 test acc  0.9383, time 24.8 sec
# epoch 416, loss 0.002592, train acc 1.000000, sy19 test acc  0.7567, sy20 test acc  0.9358, time 24.8 sec
# epoch 417, loss 0.002661, train acc 1.000000, sy19 test acc  0.7572, sy20 test acc  0.9359, time 24.8 sec
# epoch 418, loss 0.002507, train acc 0.999700, sy19 test acc  0.7575, sy20 test acc  0.9390, time 24.8 sec
# epoch 419, loss 0.002633, train acc 1.000000, sy19 test acc  0.7574, sy20 test acc  0.9365, time 24.8 sec
# epoch 420, loss 0.002612, train acc 1.000000, sy19 test acc  0.7568, sy20 test acc  0.9386, time 24.8 sec
# epoch 421, loss 0.002368, train acc 1.000000, sy19 test acc  0.7563, sy20 test acc  0.9372, time 24.8 sec
# epoch 422, loss 0.002370, train acc 0.999850, sy19 test acc  0.7552, sy20 test acc  0.9409, time 24.8 sec
# epoch 423, loss 0.002692, train acc 1.000000, sy19 test acc  0.7578, sy20 test acc  0.9349, time 24.8 sec
# epoch 424, loss 0.002427, train acc 0.999850, sy19 test acc  0.7575, sy20 test acc  0.9370, time 24.8 sec
# epoch 425, loss 0.002406, train acc 0.999850, sy19 test acc  0.7572, sy20 test acc  0.9362, time 24.8 sec
# epoch 426, loss 0.002203, train acc 0.999850, sy19 test acc  0.7573, sy20 test acc  0.9357, time 24.8 sec
# epoch 427, loss 0.002464, train acc 0.999850, sy19 test acc  0.7573, sy20 test acc  0.9353, time 24.8 sec
# epoch 428, loss 0.002762, train acc 0.999850, sy19 test acc  0.7577, sy20 test acc  0.9359, time 24.8 sec
# epoch 429, loss 0.002529, train acc 0.999700, sy19 test acc  0.7572, sy20 test acc  0.9363, time 24.8 sec
# epoch 430, loss 0.002380, train acc 1.000000, sy19 test acc  0.7570, sy20 test acc  0.9352, time 24.8 sec
# epoch 431, loss 0.002508, train acc 1.000000, sy19 test acc  0.7572, sy20 test acc  0.9368, time 24.8 sec
# epoch 432, loss 0.002874, train acc 0.999700, sy19 test acc  0.7571, sy20 test acc  0.9363, time 24.8 sec
# epoch 433, loss 0.002520, train acc 1.000000, sy19 test acc  0.7573, sy20 test acc  0.9389, time 24.7 sec
# epoch 434, loss 0.002512, train acc 0.999850, sy19 test acc  0.7574, sy20 test acc  0.9356, time 24.8 sec
# epoch 435, loss 0.002572, train acc 0.999700, sy19 test acc  0.7568, sy20 test acc  0.9363, time 24.8 sec
# epoch 436, loss 0.003384, train acc 0.999700, sy19 test acc  0.7576, sy20 test acc  0.9395, time 24.8 sec
# epoch 437, loss 0.002622, train acc 1.000000, sy19 test acc  0.7549, sy20 test acc  0.9407, time 24.8 sec
# epoch 438, loss 0.002981, train acc 0.999549, sy19 test acc  0.7575, sy20 test acc  0.9366, time 24.8 sec
# epoch 439, loss 0.002545, train acc 1.000000, sy19 test acc  0.7570, sy20 test acc  0.9353, time 24.8 sec
# epoch 440, loss 0.002539, train acc 0.999700, sy19 test acc  0.7565, sy20 test acc  0.9396, time 24.8 sec
# epoch 441, loss 0.002290, train acc 1.000000, sy19 test acc  0.7565, sy20 test acc  0.9374, time 24.8 sec
# epoch 442, loss 0.002714, train acc 0.999700, sy19 test acc  0.7554, sy20 test acc  0.9400, time 24.8 sec
# epoch 443, loss 0.002638, train acc 0.999700, sy19 test acc  0.7574, sy20 test acc  0.9371, time 24.8 sec
# epoch 444, loss 0.002582, train acc 0.999850, sy19 test acc  0.7541, sy20 test acc  0.9392, time 24.8 sec
# epoch 445, loss 0.002940, train acc 0.999700, sy19 test acc  0.7570, sy20 test acc  0.9363, time 24.8 sec
# epoch 446, loss 0.002473, train acc 0.999850, sy19 test acc  0.7576, sy20 test acc  0.9370, time 24.8 sec
# epoch 447, loss 0.002140, train acc 1.000000, sy19 test acc  0.7543, sy20 test acc  0.9393, time 24.8 sec
# epoch 448, loss 0.002499, train acc 1.000000, sy19 test acc  0.7571, sy20 test acc  0.9374, time 24.8 sec
# epoch 449, loss 0.002417, train acc 0.999850, sy19 test acc  0.7578, sy20 test acc  0.9355, time 24.8 sec
# epoch 450, loss 0.002994, train acc 0.999549, sy19 test acc  0.7574, sy20 test acc  0.9354, time 24.8 sec
# epoch 451, loss 0.002316, train acc 1.000000, sy19 test acc  0.7570, sy20 test acc  0.9369, time 24.8 sec
# epoch 452, loss 0.002523, train acc 0.999700, sy19 test acc  0.7572, sy20 test acc  0.9363, time 24.8 sec
# epoch 453, loss 0.002739, train acc 0.999700, sy19 test acc  0.7575, sy20 test acc  0.9355, time 24.8 sec
# epoch 454, loss 0.002248, train acc 1.000000, sy19 test acc  0.7578, sy20 test acc  0.9359, time 24.8 sec
# epoch 455, loss 0.002568, train acc 0.999850, sy19 test acc  0.7553, sy20 test acc  0.9374, time 24.8 sec
# epoch 456, loss 0.002684, train acc 0.999700, sy19 test acc  0.7552, sy20 test acc  0.9400, time 24.8 sec
# epoch 457, loss 0.002470, train acc 1.000000, sy19 test acc  0.7573, sy20 test acc  0.9377, time 24.8 sec
# epoch 458, loss 0.002463, train acc 0.999850, sy19 test acc  0.7574, sy20 test acc  0.9373, time 24.8 sec
# epoch 459, loss 0.002121, train acc 1.000000, sy19 test acc  0.7574, sy20 test acc  0.9364, time 24.8 sec
# epoch 460, loss 0.002540, train acc 1.000000, sy19 test acc  0.7553, sy20 test acc  0.9385, time 24.8 sec
# epoch 461, loss 0.002522, train acc 1.000000, sy19 test acc  0.7577, sy20 test acc  0.9363, time 24.8 sec
# epoch 462, loss 0.002184, train acc 1.000000, sy19 test acc  0.7573, sy20 test acc  0.9334, time 24.8 sec
# epoch 463, loss 0.002522, train acc 0.999700, sy19 test acc  0.7570, sy20 test acc  0.9354, time 24.8 sec
# epoch 464, loss 0.002361, train acc 1.000000, sy19 test acc  0.7570, sy20 test acc  0.9357, time 24.8 sec
# epoch 465, loss 0.002272, train acc 1.000000, sy19 test acc  0.7556, sy20 test acc  0.9377, time 24.8 sec
# epoch 466, loss 0.002390, train acc 0.999850, sy19 test acc  0.7576, sy20 test acc  0.9386, time 24.8 sec
# epoch 467, loss 0.002764, train acc 0.999399, sy19 test acc  0.7571, sy20 test acc  0.9384, time 24.8 sec
# epoch 468, loss 0.002811, train acc 0.999850, sy19 test acc  0.7565, sy20 test acc  0.9363, time 24.8 sec
# epoch 469, loss 0.002773, train acc 0.999700, sy19 test acc  0.7577, sy20 test acc  0.9353, time 24.8 sec
# epoch 470, loss 0.002503, train acc 1.000000, sy19 test acc  0.7577, sy20 test acc  0.9362, time 24.8 sec
# epoch 471, loss 0.002610, train acc 0.999700, sy19 test acc  0.7575, sy20 test acc  0.9364, time 24.8 sec
# epoch 472, loss 0.002785, train acc 1.000000, sy19 test acc  0.7576, sy20 test acc  0.9365, time 24.8 sec
# epoch 473, loss 0.002385, train acc 0.999850, sy19 test acc  0.7572, sy20 test acc  0.9360, time 24.8 sec
# epoch 474, loss 0.002737, train acc 0.999700, sy19 test acc  0.7573, sy20 test acc  0.9361, time 24.8 sec
# epoch 475, loss 0.002447, train acc 0.999850, sy19 test acc  0.7568, sy20 test acc  0.9368, time 24.8 sec
# epoch 476, loss 0.002541, train acc 0.999850, sy19 test acc  0.7575, sy20 test acc  0.9362, time 24.8 sec
# epoch 477, loss 0.002254, train acc 1.000000, sy19 test acc  0.7564, sy20 test acc  0.9371, time 24.8 sec
# epoch 478, loss 0.002760, train acc 0.999549, sy19 test acc  0.7576, sy20 test acc  0.9354, time 24.8 sec
# epoch 479, loss 0.002965, train acc 0.999399, sy19 test acc  0.7574, sy20 test acc  0.9340, time 24.8 sec
# epoch 480, loss 0.002936, train acc 0.999850, sy19 test acc  0.7577, sy20 test acc  0.9356, time 24.8 sec
# epoch 481, loss 0.002360, train acc 0.999850, sy19 test acc  0.7575, sy20 test acc  0.9365, time 24.8 sec
# epoch 482, loss 0.002421, train acc 1.000000, sy19 test acc  0.7572, sy20 test acc  0.9370, time 24.8 sec
# epoch 483, loss 0.002637, train acc 0.999850, sy19 test acc  0.7552, sy20 test acc  0.9369, time 24.8 sec
# epoch 484, loss 0.002428, train acc 0.999700, sy19 test acc  0.7570, sy20 test acc  0.9367, time 24.8 sec
# epoch 485, loss 0.002711, train acc 0.999850, sy19 test acc  0.7572, sy20 test acc  0.9359, time 24.8 sec
# epoch 486, loss 0.002491, train acc 1.000000, sy19 test acc  0.7566, sy20 test acc  0.9366, time 24.8 sec
# epoch 487, loss 0.002164, train acc 1.000000, sy19 test acc  0.7553, sy20 test acc  0.9385, time 24.8 sec
# epoch 488, loss 0.002925, train acc 0.999850, sy19 test acc  0.7553, sy20 test acc  0.9427, time 24.8 sec
# epoch 489, loss 0.002738, train acc 0.999549, sy19 test acc  0.7573, sy20 test acc  0.9389, time 24.8 sec
# epoch 490, loss 0.002198, train acc 1.000000, sy19 test acc  0.7554, sy20 test acc  0.9383, time 24.8 sec
# epoch 491, loss 0.002109, train acc 0.999850, sy19 test acc  0.7548, sy20 test acc  0.9400, time 24.8 sec
# epoch 492, loss 0.001894, train acc 1.000000, sy19 test acc  0.7572, sy20 test acc  0.9377, time 24.8 sec
# epoch 493, loss 0.002457, train acc 0.999850, sy19 test acc  0.7573, sy20 test acc  0.9361, time 24.8 sec
# epoch 494, loss 0.002505, train acc 0.999850, sy19 test acc  0.7578, sy20 test acc  0.9362, time 24.8 sec
# epoch 495, loss 0.002089, train acc 1.000000, sy19 test acc  0.7572, sy20 test acc  0.9363, time 24.8 sec
# epoch 496, loss 0.002312, train acc 1.000000, sy19 test acc  0.7574, sy20 test acc  0.9368, time 24.8 sec
# epoch 497, loss 0.002396, train acc 0.999850, sy19 test acc  0.7567, sy20 test acc  0.9377, time 24.8 sec
# epoch 498, loss 0.002292, train acc 1.000000, sy19 test acc  0.7549, sy20 test acc  0.9380, time 24.8 sec
# epoch 499, loss 0.002334, train acc 1.000000, sy19 test acc  0.7571, sy20 test acc  0.9345, time 24.8 sec
# epoch 500, loss 0.002275, train acc 1.000000, sy19 test acc  0.7575, sy20 test acc  0.9363, time 24.8 sec

# %%
## save results
acc_lists = pd.DataFrame({'loss': loss_list, 'train_acc':train_acc_list, 'sy19_test_acc': sy19_test_acc_list, 'sy20_test_acc': sy20_test_acc_list})
acc_lists_filename = 'acc-list-cuda0-'+str(datetime.datetime.now()).replace(' ','-').replace(':','-').replace('.','-')+'.csv'
acc_lists.to_csv('./runs/'+acc_lists_filename)
print(acc_lists_filename)

model_filename = './runs/'+'model-cuda0-'+str(datetime.datetime.now()).replace(' ','-').replace(':','-').replace('.','-')+'.pt'
torch.save(net.state_dict(), 'model_filename')
print(model_filename)
# Out:
# acc-list-cuda0-2019-11-30-01-42-27-690094.csv
# ./runs/model-cuda0-2019-11-30-01-42-27-694663.pt

# %%
# save figure
fig = plt.figure(figsize=(8,6))
epoches = np.linspace(1,len(loss_list),len(loss_list))
plt.plot(epoches, train_acc_list, '-', linewidth=1,label='Train Accuracy: Total')
plt.plot(epoches, sy19_test_acc_list, '-', linewidth=1,label='Test Accuracy: Seyfert 1.9')
plt.plot(epoches, sy20_test_acc_list, '-', linewidth=1,label='Test Accuracy: Seyfert 2.0')
plt.plot(epoches, loss_list,'-', linewidth=1,label='Train Loss')


plt.axhline(y=1.0,color='grey',linestyle='solid',linewidth=0.5, alpha=0.5, label='')
plt.axhline(y=0.938,color='green',linestyle='dashed',linewidth=0.5,  label='Accuracy: 93.8%')
plt.axhline(y=0.757,color='orange',linestyle='dashed',linewidth=0.5,  label='Accuracy: 75.7%')
plt.axhline(y=0,color='grey',linestyle='solid',linewidth=0.5,  alpha=0.5, label='')

plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Accuracy & Loss')

plt.xlim(-1,500)
plt.ylim(-0.02,1.05)

figure_filename = './runs/'+'model-cuda3-'+str(datetime.datetime.now()).replace(' ','-').replace(':','-').replace('.','-')+'.pdf'
fig.tight_layout()
plt.savefig(figure_filename, format='pdf')

# %%
plt.semilogy(epoches, loss_list,label='loss')
plt.legend()
